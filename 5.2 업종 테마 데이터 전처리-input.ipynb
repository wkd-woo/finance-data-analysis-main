# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/finance-data-analysis/blob/main/5.2%20%EC%97%85%EC%A2%85%20%ED%85%8C%EB%A7%88%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%A0%84%EC%B2%98%EB%A6%AC-input.ipynb)
#
# ## 업종/테마 전처리 미션확인
#
# * 팀장님이 우리 회사와 유사한 업종과 테마로 사업을 하고 있는 종목을 수집해서 분석해 달라는 미션을 주셨습니다.
# * 코스피에서 해당 업종 혹은 테마의 시가총액이 가장 많은 종목을 찾아주세요.
# * 해당 업종/테마의 거래량이 가장 많은 종목을 찾아주세요.
# * 최근 52주 최고가에서 현재가 기준으로 가장 손실이 크게 난 종목은 어떤 종목일까요?
# * 거래대금이 20위 안에 있는 코스피 종목 중에 "PER"가 가장 낮은 종목은 무엇일까요?
#
#
# ### 주요 업종/테마
#
# * 실습에 참고해 보세요.
# * 제약 업종 : https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=35
# * 의료기기 : https://finance.naver.com/sise/sise_group_detail.nhn?type=theme&no=175
# * 코로나19(덱사메타손) : https://finance.naver.com/sise/sise_group_detail.nhn?type=theme&no=442
# * 제약업체 : https://finance.naver.com/sise/sise_group_detail.nhn?type=theme&no=172
# * 바이오시밀러(복제 바이오의약품) : https://finance.naver.com/sise/sise_group_detail.nhn?type=theme&no=241

# %%
# 라이브러리 로드하기 : 데이터 분석을 위한 pandas, 수치계산을 위한 numpy
import pandas as pd
import numpy as np

# %%
# 4.업종/테마주 수집시에 저장해 두었던 csv 파일을 다시 읽어옵니다.
# 'upjong_no_35_연-월-일.csv'
# 종목코드는 꼭 문자형태로 불러옵니다. dtype={"종목코드":np.object}
file_name = "theme_no_64_2022-01-25.csv"
pd.read_csv(file_name)
raw = pd.read_csv(file_name, dtype={"종목코드":np.object})
raw.shape
# Out:
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/1616766275.py:6: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   raw = pd.read_csv(file_name, dtype={"종목코드":np.object})
# (97, 47)

# %%
# 미리보기 합니다.
raw.head(5)
# Out:
#         종목명     종목명.1       현재가     전일비     등락률      매수호가      매도호가  \
# 0     삼아알미늄  테마 편입 사유   28050.0  1100.0  +4.08%   28150.0   28200.0
# 1    에이프로 *  테마 편입 사유   38050.0   800.0  +2.15%   38150.0   38200.0
# 2       알루코  테마 편입 사유    3970.0    60.0  +1.53%    4005.0    4010.0
# 3  에코프로비엠 *  테마 편입 사유  405400.0  5000.0  +1.25%  405000.0  405100.0
# 4    원방테크 *  테마 편입 사유   13800.0   150.0  +1.10%   13850.0   13900.0
#
#           거래량      거래대금      전일거래량  ...             52주최고l최저  \
# 0    470144.0   13046.0   133848.0  ...     45,600  l  9,150
# 1    217060.0    8314.0  1656641.0  ...    54,400  l  27,050
# 2  23287831.0   97848.0  4906626.0  ...      6,200  l  3,000
# 3    316436.0  129130.0   730341.0  ...  575,100  l  145,200
# 4    317443.0    4527.0   133205.0  ...    36,550  l  13,050
#
#      PERlEPS(2021.09)          추정PERlEPS   PBRlBPS (2021.09)  배당수익률  동일업종 PER  \
# 0     30.51배  l  926원        N/A  l  N/A   2.61배  l  10,809원    NaN    10.20배
# 1     N/A  l  -1,064원        N/A  l  N/A    4.93배  l  7,752원    NaN    24.22배
# 2       N/A  l  -184원        N/A  l  N/A    1.51배  l  2,637원    NaN    10.20배
# 3  109.17배  l  3,718원  89.00배  l  4,566원  17.28배  l  23,486원    NaN    54.11배
# 4     39.09배  l  353원        N/A  l  N/A   1.28배  l  10,772원    NaN    34.69배
#
#    동일업종 등락률  배당수익률l2021.12  PERlEPS(2020.12)  PBRlBPS (2020.12)
# 0    -1.79%            NaN               NaN                NaN
# 1    -3.12%            NaN               NaN                NaN
# 2    -1.79%            NaN               NaN                NaN
# 3    -4.45%          0.23%               NaN                NaN
# 4    -3.76%            NaN               NaN                NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ## 전체 컬럼 출력하기

# %%
# 전체 컬럼이 출력되도록 display 설정을 변경합니다.
pd.options.display.max_columns = None

# %%
# 전체 컬럼이 보이는지 확인합니다.
raw.head()
# Out:
#         종목명     종목명.1       현재가     전일비     등락률      매수호가      매도호가  \
# 0     삼아알미늄  테마 편입 사유   28050.0  1100.0  +4.08%   28150.0   28200.0
# 1    에이프로 *  테마 편입 사유   38050.0   800.0  +2.15%   38150.0   38200.0
# 2       알루코  테마 편입 사유    3970.0    60.0  +1.53%    4005.0    4010.0
# 3  에코프로비엠 *  테마 편입 사유  405400.0  5000.0  +1.25%  405000.0  405100.0
# 4    원방테크 *  테마 편입 사유   13800.0   150.0  +1.10%   13850.0   13900.0
#
#           거래량      거래대금      전일거래량        조회일자 종목명_전처리    종목코드     매출액   영업이익  \
# 0    470144.0   13046.0   133848.0  2022-01-25   삼아알미늄  006110     NaN    NaN
# 1    217060.0    8314.0  1656641.0  2022-01-25    에이프로  262260     NaN    NaN
# 2  23287831.0   97848.0  4906626.0  2022-01-25     알루코  001780     NaN    NaN
# 3    316436.0  129130.0   730341.0  2022-01-25  에코프로비엠  247540  4443.0  403.0
# 4    317443.0    4527.0   133205.0  2022-01-25    원방테크  053080     NaN    NaN
#
#    당기순이익  영업이익률  순이익률  ROE(지배주주)  부채비율  당좌비율  유보율  EPS(원)  PER(배)   BPS(원)  \
# 0    NaN    NaN   NaN        NaN   NaN   NaN  NaN     NaN     NaN      NaN
# 1    NaN    NaN   NaN        NaN   NaN   NaN  NaN     NaN     NaN   8236.0
# 2    NaN    NaN   NaN        NaN   NaN   NaN  NaN     NaN     NaN      NaN
# 3  332.0   9.08  7.46        NaN   NaN   NaN  NaN  1423.0  281.34  31929.0
# 4    NaN    NaN   NaN        NaN   NaN   NaN  NaN     NaN     NaN      NaN
#
#    PBR(배)  주당배당금(원)  시가배당률(%)  배당성향(%)           시가총액    시가총액순위     상장주식수  \
# 0     NaN       NaN       NaN      NaN      3,108  억원  코스피 458위  11000000
# 1    4.52       NaN       NaN      NaN      2,699  억원  코스닥 322위   7065942
# 2     NaN       NaN       NaN      NaN      3,565  억원  코스피 416위  89791232
# 3   12.54       NaN       NaN      NaN  9조  3,030  억원    코스닥 2위  22919466
# 4     NaN       NaN       NaN      NaN      1,794  억원  코스닥 515위  12999807
#
#       액면가l매매단위  외국인한도주식수(A)  외국인보유주식수(B) 외국인소진율(B/A)           투자의견l목표주가  \
# 0  500원  l  1주     11000000      3653946      33.22%         N/A  l  N/A
# 1  500원  l  1주      7065942        53295       0.75%         N/A  l  N/A
# 2  500원  l  1주     89791232      1612229       1.80%         N/A  l  N/A
# 3  500원  l  1주     22919466      3613998      15.77%  4.00매수  l  628,488
# 4  500원  l  1주     12999807         9398       0.07%         N/A  l  N/A
#
#               52주최고l최저    PERlEPS(2021.09)          추정PERlEPS  \
# 0     45,600  l  9,150     30.51배  l  926원        N/A  l  N/A
# 1    54,400  l  27,050     N/A  l  -1,064원        N/A  l  N/A
# 2      6,200  l  3,000       N/A  l  -184원        N/A  l  N/A
# 3  575,100  l  145,200  109.17배  l  3,718원  89.00배  l  4,566원
# 4    36,550  l  13,050     39.09배  l  353원        N/A  l  N/A
#
#     PBRlBPS (2021.09)  배당수익률 동일업종 PER 동일업종 등락률 배당수익률l2021.12 PERlEPS(2020.12)  \
# 0   2.61배  l  10,809원    NaN   10.20배   -1.79%           NaN              NaN
# 1    4.93배  l  7,752원    NaN   24.22배   -3.12%           NaN              NaN
# 2    1.51배  l  2,637원    NaN   10.20배   -1.79%           NaN              NaN
# 3  17.28배  l  23,486원    NaN   54.11배   -4.45%         0.23%              NaN
# 4   1.28배  l  10,772원    NaN   34.69배   -3.76%           NaN              NaN
#
#   PBRlBPS (2020.12)
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
# DataFrame의 column만 따로 봅니다.
raw.columns
# Out:
# Index(['종목명', '종목명.1', '현재가', '전일비', '등락률', '매수호가', '매도호가', '거래량', '거래대금',
#        '전일거래량', '조회일자', '종목명_전처리', '종목코드', '매출액', '영업이익', '당기순이익', '영업이익률',
#        '순이익률', 'ROE(지배주주)', '부채비율', '당좌비율', '유보율', 'EPS(원)', 'PER(배)',
#        'BPS(원)', 'PBR(배)', '주당배당금(원)', '시가배당률(%)', '배당성향(%)', '시가총액', '시가총액순위',
#        '상장주식수', '액면가l매매단위', '외국인한도주식수(A)', '외국인보유주식수(B)', '외국인소진율(B/A)',
#        '투자의견l목표주가', '52주최고l최저', 'PERlEPS(2021.09)', '추정PERlEPS',
#        'PBRlBPS (2021.09)', '배당수익률', '동일업종 PER', '동일업종 등락률', '배당수익률l2021.12',
#        'PERlEPS(2020.12)', 'PBRlBPS (2020.12)'],
#       dtype='object')

# %% [markdown]
# ## 결측치

# %%
raw.isnull()
# Out:
#       종목명  종목명.1    현재가    전일비    등락률   매수호가   매도호가    거래량   거래대금  전일거래량  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 92  False  False  False  False  False  False  False  False  False  False
# 93  False  False  False  False  False  False  False  False  False  False
# 94  False  False  False  False  False  False  False  False  False  False
# 95  False  False  False  False  False  False  False  False  False  False
# 96  False  False  False  False  False  False  False  False  False  False
#
#      조회일자  종목명_전처리   종목코드    매출액   영업이익  당기순이익  영업이익률   순이익률  ROE(지배주주)  부채비율  \
# 0   False    False  False   True   True   True   True   True       True  True
# 1   False    False  False   True   True   True   True   True       True  True
# 2   False    False  False   True   True   True   True   True       True  True
# 3   False    False  False  False  False  False  False  False       True  True
# 4   False    False  False   True   True   True   True   True       True  True
# ..    ...      ...    ...    ...    ...    ...    ...    ...        ...   ...
# 92  False    False  False   True   True   True   True   True       True  True
# 93  False    False  False   True   True   True   True   True       True  True
# 94  False    False  False   True   True   True   True   True       True  True
# 95  False    False  False   True   True   True   True   True       True  True
# 96  False    False  False  False  False  False  False  False       True  True
#
#     당좌비율   유보율  EPS(원)  PER(배)  BPS(원)  PBR(배)  주당배당금(원)  시가배당률(%)  배당성향(%)  \
# 0   True  True    True    True    True    True      True      True     True
# 1   True  True    True    True   False   False      True      True     True
# 2   True  True    True    True    True    True      True      True     True
# 3   True  True   False   False   False   False      True      True     True
# 4   True  True    True    True    True    True      True      True     True
# ..   ...   ...     ...     ...     ...     ...       ...       ...      ...
# 92  True  True    True    True    True    True      True      True     True
# 93  True  True    True    True   False   False      True      True     True
# 94  True  True    True    True    True    True      True      True     True
# 95  True  True    True    True    True    True      True      True     True
# 96  True  True   False   False   False   False      True      True     True
#
#      시가총액  시가총액순위  상장주식수  액면가l매매단위  외국인한도주식수(A)  외국인보유주식수(B)  외국인소진율(B/A)  \
# 0   False   False  False     False        False        False        False
# 1   False   False  False     False        False        False        False
# 2   False   False  False     False        False        False        False
# 3   False   False  False     False        False        False        False
# 4   False   False  False     False        False        False        False
# ..    ...     ...    ...       ...          ...          ...          ...
# 92  False   False  False     False        False        False        False
# 93  False   False  False     False        False        False        False
# 94  False   False  False     False        False        False        False
# 95  False   False  False     False        False        False        False
# 96  False   False  False     False        False        False        False
#
#     투자의견l목표주가  52주최고l최저  PERlEPS(2021.09)  추정PERlEPS  PBRlBPS (2021.09)  \
# 0       False     False             False      False              False
# 1       False     False             False      False              False
# 2       False     False             False      False              False
# 3       False     False             False      False              False
# 4       False     False             False      False              False
# ..        ...       ...               ...        ...                ...
# 92      False     False             False      False              False
# 93      False     False             False      False              False
# 94      False     False             False      False              False
# 95      False     False             False      False              False
# 96      False     False             False      False              False
#
#     배당수익률  동일업종 PER  동일업종 등락률  배당수익률l2021.12  PERlEPS(2020.12)  \
# 0    True     False     False           True              True
# 1    True     False     False           True              True
# 2    True     False     False           True              True
# 3    True     False     False          False              True
# 4    True     False     False           True              True
# ..    ...       ...       ...            ...               ...
# 92   True     False     False           True              True
# 93   True     False     False          False              True
# 94   True     False     False           True              True
# 95   True     False     False           True              True
# 96   True     False     False           True              True
#
#     PBRlBPS (2020.12)
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# ..                ...
# 92               True
# 93               True
# 94               True
# 95               True
# 96               True
#
# [97 rows x 47 columns]

# %%
# 결측치의 합계를 구합니다.
raw.isnull().sum()
# Out:
# 종목명                   0
# 종목명.1                 0
# 현재가                   0
# 전일비                   0
# 등락률                   0
# 매수호가                  0
# 매도호가                  0
# 거래량                   0
# 거래대금                  0
# 전일거래량                 0
# 조회일자                  0
# 종목명_전처리               0
# 종목코드                  0
# 매출액                  63
# 영업이익                 63
# 당기순이익                74
# 영업이익률                63
# 순이익률                 74
# ROE(지배주주)            97
# 부채비율                 97
# 당좌비율                 97
# 유보율                  97
# EPS(원)               70
# PER(배)               70
# BPS(원)               62
# PBR(배)               62
# 주당배당금(원)             97
# 시가배당률(%)             97
# 배당성향(%)              97
# 시가총액                  0
# 시가총액순위                0
# 상장주식수                 0
# 액면가l매매단위              0
# 외국인한도주식수(A)           0
# 외국인보유주식수(B)           0
# 외국인소진율(B/A)           0
# 투자의견l목표주가             0
# 52주최고l최저              0
# PERlEPS(2021.09)      5
# 추정PERlEPS             0
# PBRlBPS (2021.09)     5
# 배당수익률                97
# 동일업종 PER              0
# 동일업종 등락률              0
# 배당수익률l2021.12        90
# PERlEPS(2020.12)     92
# PBRlBPS (2020.12)    92
# dtype: int64

# %%
# 결측치의 비율을 구합니다.
raw.isnull().mean() * 100
# Out:
# 종목명                    0.000000
# 종목명.1                  0.000000
# 현재가                    0.000000
# 전일비                    0.000000
# 등락률                    0.000000
# 매수호가                   0.000000
# 매도호가                   0.000000
# 거래량                    0.000000
# 거래대금                   0.000000
# 전일거래량                  0.000000
# 조회일자                   0.000000
# 종목명_전처리                0.000000
# 종목코드                   0.000000
# 매출액                   64.948454
# 영업이익                  64.948454
# 당기순이익                 76.288660
# 영업이익률                 64.948454
# 순이익률                  76.288660
# ROE(지배주주)            100.000000
# 부채비율                 100.000000
# 당좌비율                 100.000000
# 유보율                  100.000000
# EPS(원)                72.164948
# PER(배)                72.164948
# BPS(원)                63.917526
# PBR(배)                63.917526
# 주당배당금(원)             100.000000
# 시가배당률(%)             100.000000
# 배당성향(%)              100.000000
# 시가총액                   0.000000
# 시가총액순위                 0.000000
# 상장주식수                  0.000000
# 액면가l매매단위               0.000000
# 외국인한도주식수(A)            0.000000
# 외국인보유주식수(B)            0.000000
# 외국인소진율(B/A)            0.000000
# 투자의견l목표주가              0.000000
# 52주최고l최저               0.000000
# PERlEPS(2021.09)       5.154639
# 추정PERlEPS              0.000000
# PBRlBPS (2021.09)      5.154639
# 배당수익률                100.000000
# 동일업종 PER               0.000000
# 동일업종 등락률               0.000000
# 배당수익률l2021.12         92.783505
# PERlEPS(2020.12)      94.845361
# PBRlBPS (2020.12)     94.845361
# dtype: float64

# %%
# 결측치 제거 전에 행과 열의 수를 봅니다.
raw.shape
# Out:
# (97, 47)

# %%
# 전체가 결측치인 컬럼은 삭제 합니다.
df = raw.dropna(axis=1, how="all").copy()
df
# Out:
#          종목명     종목명.1       현재가     전일비      등락률      매수호가      매도호가  \
# 0      삼아알미늄  테마 편입 사유   28050.0  1100.0   +4.08%   28150.0   28200.0
# 1     에이프로 *  테마 편입 사유   38050.0   800.0   +2.15%   38150.0   38200.0
# 2        알루코  테마 편입 사유    3970.0    60.0   +1.53%    4005.0    4010.0
# 3   에코프로비엠 *  테마 편입 사유  405400.0  5000.0   +1.25%  405000.0  405100.0
# 4     원방테크 *  테마 편입 사유   13800.0   150.0   +1.10%   13850.0   13900.0
# ..       ...       ...       ...     ...      ...       ...       ...
# 92    디이엔티 *  테마 편입 사유    5400.0   570.0   -9.55%    5380.0    5390.0
# 93    브이원텍 *  테마 편입 사유    9820.0  1230.0  -11.13%    9920.0    9940.0
# 94    나인테크 *  테마 편입 사유    4935.0   645.0  -11.56%    5030.0    5040.0
# 95   나라엠앤디 *  테마 편입 사유   11500.0  1550.0  -11.88%   11750.0   11800.0
# 96    PI첨단소재  테마 편입 사유   42700.0  6950.0  -14.00%   42750.0   42800.0
#
#            거래량      거래대금       전일거래량        조회일자 종목명_전처리    종목코드     매출액  \
# 0     470144.0   13046.0    133848.0  2022-01-25   삼아알미늄  006110     NaN
# 1     217060.0    8314.0   1656641.0  2022-01-25    에이프로  262260     NaN
# 2   23287831.0   97848.0   4906626.0  2022-01-25     알루코  001780     NaN
# 3     316436.0  129130.0    730341.0  2022-01-25  에코프로비엠  247540  4443.0
# 4     317443.0    4527.0    133205.0  2022-01-25    원방테크  053080     NaN
# ..         ...       ...         ...         ...     ...     ...     ...
# 92    283199.0    1566.0    410992.0  2022-01-25    디이엔티  079810     NaN
# 93    633024.0    6493.0    508320.0  2022-01-25    브이원텍  251630     NaN
# 94   3407339.0   17772.0  12491739.0  2022-01-25    나인테크  267320     NaN
# 95   1410582.0   17167.0   1864384.0  2022-01-25   나라엠앤디  051490     NaN
# 96    814638.0   35939.0    212149.0  2022-01-25  PI첨단소재  178920   718.0
#
#      영업이익  당기순이익  영업이익률   순이익률  EPS(원)  PER(배)   BPS(원)  PBR(배)  \
# 0     NaN    NaN    NaN    NaN     NaN     NaN      NaN     NaN
# 1     NaN    NaN    NaN    NaN     NaN     NaN   8236.0    4.52
# 2     NaN    NaN    NaN    NaN     NaN     NaN      NaN     NaN
# 3   403.0  332.0   9.08   7.46  1423.0  281.34  31929.0   12.54
# 4     NaN    NaN    NaN    NaN     NaN     NaN      NaN     NaN
# ..    ...    ...    ...    ...     ...     ...      ...     ...
# 92    NaN    NaN    NaN    NaN     NaN     NaN      NaN     NaN
# 93    NaN    NaN    NaN    NaN     NaN     NaN   6221.0    1.78
# 94    NaN    NaN    NaN    NaN     NaN     NaN      NaN     NaN
# 95    NaN    NaN    NaN    NaN     NaN     NaN      NaN     NaN
# 96  152.0  106.0  21.16  14.81   362.0  141.72  10882.0    4.71
#
#              시가총액     시가총액순위     상장주식수     액면가l매매단위  외국인한도주식수(A)  외국인보유주식수(B)  \
# 0       3,108  억원   코스피 458위  11000000  500원  l  1주     11000000      3653946
# 1       2,699  억원   코스닥 322위   7065942  500원  l  1주      7065942        53295
# 2       3,565  억원   코스피 416위  89791232  500원  l  1주     89791232      1612229
# 3   9조  3,030  억원     코스닥 2위  22919466  500원  l  1주     22919466      3613998
# 4       1,794  억원   코스닥 515위  12999807  500원  l  1주     12999807         9398
# ..            ...        ...       ...          ...          ...          ...
# 92        772  억원  코스닥 1081위  14182641  500원  l  1주     14182641       145864
# 93      1,495  억원   코스닥 626위  15050580  500원  l  1주     15050580        95268
# 94      1,978  억원   코스닥 467위  39396554  100원  l  1주     39396554        91630
# 95      1,661  억원   코스닥 568위  14200000  500원  l  1주     14200000       111174
# 96  1조  2,569  억원   코스피 189위  29366322  500원  l  1주     29366322      3788688
#
#    외국인소진율(B/A)           투자의견l목표주가             52주최고l최저    PERlEPS(2021.09)  \
# 0       33.22%         N/A  l  N/A     45,600  l  9,150     30.51배  l  926원
# 1        0.75%         N/A  l  N/A    54,400  l  27,050     N/A  l  -1,064원
# 2        1.80%         N/A  l  N/A      6,200  l  3,000       N/A  l  -184원
# 3       15.77%  4.00매수  l  628,488  575,100  l  145,200  109.17배  l  3,718원
# 4        0.07%         N/A  l  N/A    36,550  l  13,050     39.09배  l  353원
# ..         ...                 ...                  ...                 ...
# 92       1.03%         N/A  l  N/A     11,900  l  2,850       N/A  l  -366원
# 93       0.63%         N/A  l  N/A     14,000  l  7,450     20.60배  l  482원
# 94       0.23%         N/A  l  N/A      6,530  l  2,580       N/A  l  -128원
# 95       0.78%         N/A  l  N/A     16,400  l  8,390     49.58배  l  236원
# 96      12.90%   4.00매수  l  65,375    67,800  l  38,350   21.49배  l  1,992원
#
#             추정PERlEPS   PBRlBPS (2021.09) 동일업종 PER 동일업종 등락률 배당수익률l2021.12  \
# 0         N/A  l  N/A   2.61배  l  10,809원   10.20배   -1.79%           NaN
# 1         N/A  l  N/A    4.93배  l  7,752원   24.22배   -3.12%           NaN
# 2         N/A  l  N/A    1.51배  l  2,637원   10.20배   -1.79%           NaN
# 3   89.00배  l  4,566원  17.28배  l  23,486원   54.11배   -4.45%         0.23%
# 4         N/A  l  N/A   1.28배  l  10,772원   34.69배   -3.76%           NaN
# ..                ...                 ...      ...      ...           ...
# 92        N/A  l  N/A    3.39배  l  1,607원   38.83배   -3.83%           NaN
# 93        N/A  l  N/A    1.53배  l  6,505원   24.22배   -2.94%         1.01%
# 94        N/A  l  N/A      8.14배  l  617원   12.86배   -2.16%           NaN
# 95        N/A  l  N/A    1.90배  l  6,165원   34.69배   -3.76%           NaN
# 96  18.00배  l  2,320원   4.06배  l  10,552원   10.40배   -4.29%           NaN
#
#    PERlEPS(2020.12) PBRlBPS (2020.12)
# 0               NaN               NaN
# 1               NaN               NaN
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN
# ..              ...               ...
# 92              NaN               NaN
# 93              NaN               NaN
# 94              NaN               NaN
# 95              NaN               NaN
# 96              NaN               NaN
#
# [97 rows x 39 columns]

# %%
# 삭제된 컬럼의 수를 계산해 봅니다.

raw.shape[1] - df.shape[1]
# Out:
# 8

# %%
# info를 통해 결측치 데이터 타입을 확인합니다.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   종목명                97 non-null     object
#  1   종목명.1              97 non-null     object
#  2   현재가                97 non-null     float64
#  3   전일비                97 non-null     float64
#  4   등락률                97 non-null     object
#  5   매수호가               97 non-null     float64
#  6   매도호가               97 non-null     float64
#  7   거래량                97 non-null     float64
#  8   거래대금               97 non-null     float64
#  9   전일거래량              97 non-null     float64
#  10  조회일자               97 non-null     object
#  11  종목명_전처리            97 non-null     object
#  12  종목코드               97 non-null     object
#  13  매출액                34 non-null     float64
#  14  영업이익               34 non-null     float64
#  15  당기순이익              23 non-null     float64
#  16  영업이익률              34 non-null     float64
#  17  순이익률               23 non-null     float64
#  18  EPS(원)             27 non-null     float64
#  19  PER(배)             27 non-null     float64
#  20  BPS(원)             35 non-null     float64
#  21  PBR(배)             35 non-null     float64
#  22  시가총액               97 non-null     object
#  23  시가총액순위             97 non-null     object
#  24  상장주식수              97 non-null     int64
#  25  액면가l매매단위           97 non-null     object
#  26  외국인한도주식수(A)        97 non-null     int64
#  27  외국인보유주식수(B)        97 non-null     int64
#  28  외국인소진율(B/A)        97 non-null     object
#  29  투자의견l목표주가          97 non-null     object
#  30  52주최고l최저           97 non-null     object
#  31  PERlEPS(2021.09)   92 non-null     object
#  32  추정PERlEPS          97 non-null     object
#  33  PBRlBPS (2021.09)  92 non-null     object
#  34  동일업종 PER           97 non-null     object
#  35  동일업종 등락률           97 non-null     object
#  36  배당수익률l2021.12      7 non-null      object
#  37  PERlEPS(2020.12)   5 non-null      object
#  38  PBRlBPS (2020.12)  5 non-null      object
# dtypes: float64(16), int64(3), object(20)
# memory usage: 29.7+ KB

# %% [markdown]
# ## 파생변수 만들기와 텍스트 데이터 다루기
# <img src="https://pandas.pydata.org/docs/_images/05_newcolumn_1.svg">
#
# * 코스피/코스닥 구분 만들기
# * 시가총액 순위 분리하기
# * 액면가l매매단위
# * 52주최고l최저

# %% [markdown]
# ### 코스피/코스닥 컬럼 만들기

# %%
# "코스피/코스닥" 컬럼을 만듭니다.
#  * 는 코스닥 종목입니다. str.endswith 를 사용합니다.
df.loc[df["종목명"].str.endswith("*"),"코스피/코스닥"] = "코스닥"
df.loc[~df["종목명"].str.endswith("*"),"코스피/코스닥"] = "코스피"

# %%
df["코스피/코스닥"].tail()
# Out:
# 92    코스닥
# 93    코스닥
# 94    코스닥
# 95    코스닥
# 96    코스피
# Name: 코스피/코스닥, dtype: object

# %%
# "코스피/코스닥" 빈도수를 확인합니다.
df["코스피/코스닥"].value_counts()
# Out:
# 코스닥    66
# 코스피    31
# Name: 코스피/코스닥, dtype: int64

# %% [markdown]
# ###  시가총액 수치형태로 만들기

# %%
# or를 의미하는 | 는 엔터키 위에 있는 키를 shift키를 누르면 나옵니다.
# df['시가총액(억원)']
df["시가총액(억원)"] = df["시가총액"].str.replace("억원","")
df["시가총액(억원)"] = df["시가총액(억원)"].str.replace("조|,","")
df["시가총액(억원)"] = df["시가총액(억원)"].str.replace(" ", "")
df["시가총액(억원)"].str.strip()
df["시가총액(억원)"] = df["시가총액(억원)"].astype(int)
df["시가총액(억원)"]
# Out:
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/475090063.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["시가총액(억원)"] = df["시가총액(억원)"].str.replace("조|,","")
# 0      3108
# 1      2699
# 2      3565
# 3     93030
# 4      1794
#       ...
# 92      772
# 93     1495
# 94     1978
# 95     1661
# 96    12569
# Name: 시가총액(억원), Length: 97, dtype: int32

# %% [markdown]
# * [정규 표현식 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EC%A0%95%EA%B7%9C_%ED%91%9C%ED%98%84%EC%8B%9D)

# %%
# 정규표현식을 사용한 숫자 추출
df["시가총액(억원)"] = df["시가총액"].str.replace("[^0-9]","").astype(int)
df["시가총액(억원)"]
# Out:
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/2768778440.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["시가총액(억원)"] = df["시가총액"].str.replace("[^0-9]","").astype(int)
# 0      3108
# 1      2699
# 2      3565
# 3     93030
# 4      1794
#       ...
# 92      772
# 93     1495
# 94     1978
# 95     1661
# 96    12569
# Name: 시가총액(억원), Length: 97, dtype: int32

# %% [markdown]
# ### 시가총액 순위 수치데이터로 만들기

# %%
# split을 사용하는 방법
# '시가총액순위(전처리)' column에서도 '위'를 빼고 수치데이터로 변경합니다.
# df["시가총액순위(전처리)"]
df["시가총액순위(전처리)"] = df["시가총액순위"].str.split(" ", expand=True)[1]
df["시가총액순위(전처리)"] = df["시가총액순위(전처리)"].str.replace("위", "").astype(int)
df["시가총액순위(전처리)"]
# Out:
# 0      458
# 1      322
# 2      416
# 3        2
# 4      515
#       ...
# 92    1081
# 93     626
# 94     467
# 95     568
# 96     189
# Name: 시가총액순위(전처리), Length: 97, dtype: int32

# %%
# 정규표현식을 사용하는 방법도 있습니다. 
# 숫자를 제외한 문자는 빈문자""로 변경하도록 합니다.
df["시가총액순위(전처리)"] = df["시가총액순위"].str.replace("[^0-9]","").astype(int)
df["시가총액순위(전처리)"]
# Out:
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/965709942.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["시가총액순위(전처리)"] = df["시가총액순위"].str.replace("[^0-9]","").astype(int)
# 0      458
# 1      322
# 2      416
# 3        2
# 4      515
#       ...
# 92    1081
# 93     626
# 94     467
# 95     568
# 96     189
# Name: 시가총액순위(전처리), Length: 97, dtype: int32

# %% [markdown]
# ### 52주최고l최저

# %%
# '52주최고l최저' => 52주최고, 52주최저 두 개의  컬럼으로 나누어 전처리 합니다.

df["52주최고"] = df["52주최고l최저"].str.split("  l  ", expand=True)[0]
df["52주최저"] = df["52주최고l최저"].str.split("  l  ", expand=True)[1]

# %%
# 일부 column들을 수치형 데이터로 바꿀수 있도록 ','와 같은 문자들을 없애고
# 새로운 column에 수치형 데이터로 입력합니다.
# 이런 수치형 데이터의 column들로 새로운 데이터 column들을 생성합니다.
df["52주최고"] = df["52주최고"].str.replace("[^0-9]","").astype(int)
df["52주최저"] = df["52주최저"].str.replace("[^0-9]","").astype(int)

df.head(5)
# Out:
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/2166043102.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["52주최고"] = df["52주최고"].str.replace("[^0-9]","").astype(int)
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/2166043102.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["52주최저"] = df["52주최저"].str.replace("[^0-9]","").astype(int)
#         종목명     종목명.1       현재가     전일비     등락률      매수호가      매도호가  \
# 0     삼아알미늄  테마 편입 사유   28050.0  1100.0  +4.08%   28150.0   28200.0
# 1    에이프로 *  테마 편입 사유   38050.0   800.0  +2.15%   38150.0   38200.0
# 2       알루코  테마 편입 사유    3970.0    60.0  +1.53%    4005.0    4010.0
# 3  에코프로비엠 *  테마 편입 사유  405400.0  5000.0  +1.25%  405000.0  405100.0
# 4    원방테크 *  테마 편입 사유   13800.0   150.0  +1.10%   13850.0   13900.0
#
#           거래량      거래대금      전일거래량        조회일자 종목명_전처리    종목코드     매출액   영업이익  \
# 0    470144.0   13046.0   133848.0  2022-01-25   삼아알미늄  006110     NaN    NaN
# 1    217060.0    8314.0  1656641.0  2022-01-25    에이프로  262260     NaN    NaN
# 2  23287831.0   97848.0  4906626.0  2022-01-25     알루코  001780     NaN    NaN
# 3    316436.0  129130.0   730341.0  2022-01-25  에코프로비엠  247540  4443.0  403.0
# 4    317443.0    4527.0   133205.0  2022-01-25    원방테크  053080     NaN    NaN
#
#    당기순이익  영업이익률  순이익률  EPS(원)  PER(배)   BPS(원)  PBR(배)           시가총액  \
# 0    NaN    NaN   NaN     NaN     NaN      NaN     NaN      3,108  억원
# 1    NaN    NaN   NaN     NaN     NaN   8236.0    4.52      2,699  억원
# 2    NaN    NaN   NaN     NaN     NaN      NaN     NaN      3,565  억원
# 3  332.0   9.08  7.46  1423.0  281.34  31929.0   12.54  9조  3,030  억원
# 4    NaN    NaN   NaN     NaN     NaN      NaN     NaN      1,794  억원
#
#      시가총액순위     상장주식수     액면가l매매단위  외국인한도주식수(A)  외국인보유주식수(B) 외국인소진율(B/A)  \
# 0  코스피 458위  11000000  500원  l  1주     11000000      3653946      33.22%
# 1  코스닥 322위   7065942  500원  l  1주      7065942        53295       0.75%
# 2  코스피 416위  89791232  500원  l  1주     89791232      1612229       1.80%
# 3    코스닥 2위  22919466  500원  l  1주     22919466      3613998      15.77%
# 4  코스닥 515위  12999807  500원  l  1주     12999807         9398       0.07%
#
#             투자의견l목표주가             52주최고l최저    PERlEPS(2021.09)  \
# 0         N/A  l  N/A     45,600  l  9,150     30.51배  l  926원
# 1         N/A  l  N/A    54,400  l  27,050     N/A  l  -1,064원
# 2         N/A  l  N/A      6,200  l  3,000       N/A  l  -184원
# 3  4.00매수  l  628,488  575,100  l  145,200  109.17배  l  3,718원
# 4         N/A  l  N/A    36,550  l  13,050     39.09배  l  353원
#
#            추정PERlEPS   PBRlBPS (2021.09) 동일업종 PER 동일업종 등락률 배당수익률l2021.12  \
# 0        N/A  l  N/A   2.61배  l  10,809원   10.20배   -1.79%           NaN
# 1        N/A  l  N/A    4.93배  l  7,752원   24.22배   -3.12%           NaN
# 2        N/A  l  N/A    1.51배  l  2,637원   10.20배   -1.79%           NaN
# 3  89.00배  l  4,566원  17.28배  l  23,486원   54.11배   -4.45%         0.23%
# 4        N/A  l  N/A   1.28배  l  10,772원   34.69배   -3.76%           NaN
#
#   PERlEPS(2020.12) PBRlBPS (2020.12) 코스피/코스닥  시가총액(억원)  시가총액순위(전처리)   52주최고  \
# 0              NaN               NaN     코스피      3108          458   45600
# 1              NaN               NaN     코스닥      2699          322   54400
# 2              NaN               NaN     코스피      3565          416    6200
# 3              NaN               NaN     코스닥     93030            2  575100
# 4              NaN               NaN     코스닥      1794          515   36550
#
#     52주최저
# 0    9150
# 1   27050
# 2    3000
# 3  145200
# 4   13050

# %%
# 52주차액: 52주최고 - 52주최저 
# 52주차액비율 : 52주최고 / 52주최저 
df["52주차액"] = df["52주최고"] - df["52주최저"]
df["52주차액비율"] = df["52주최고"] / df["52주최저"]

# %%
# 현재-최고가 : 현재가 - 52주최고
# 현재/최고가비율 : 현재가 / 52주최고
df["현재-최고가"] = df["현재가"] - df["52주최고"]
df["현재/최고가비율"] = df["현재가"] / df["52주최고"]

# %%
df[["종목명", "52주차액", "52주차액비율", "52주최고", "52주최저", "현재-최고가", "현재/최고가비율"]].head()
# Out:
#         종목명   52주차액   52주차액비율   52주최고   52주최저    현재-최고가  현재/최고가비율
# 0     삼아알미늄   36450  4.983607   45600    9150  -17550.0  0.615132
# 1    에이프로 *   27350  2.011091   54400   27050  -16350.0  0.699449
# 2       알루코    3200  2.066667    6200    3000   -2230.0  0.640323
# 3  에코프로비엠 *  429900  3.960744  575100  145200 -169700.0  0.704921
# 4    원방테크 *   23500  2.800766   36550   13050  -22750.0  0.377565

# %% [markdown]
# ### 투자의견l목표주가 astype과 to_numeric

# %%
type(np.nan)
# Out:
# float

# %%
# '투자의견l목표주가' => 투자의견, 매수매도, 목표주가 컬럼으로 나누어 전처리 합니다.

df["투자의견"] = df["투자의견l목표주가"].str.split("  l  ", expand=True)[0]
df["목표주가"] = df["투자의견l목표주가"].str.split("  l  ", expand=True)[1]
df["목표주가"] = df["목표주가"].replace("N/A", np.nan).str.replace("[^0-9]","").astype(float)
df["목표주가"]
# Out:
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/2258336503.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["목표주가"] = df["목표주가"].replace("N/A", np.nan).str.replace("[^0-9]","").astype(float)
# 0          NaN
# 1          NaN
# 2          NaN
# 3     628488.0
# 4          NaN
#         ...
# 92         NaN
# 93         NaN
# 94         NaN
# 95         NaN
# 96     65375.0
# Name: 목표주가, Length: 97, dtype: float64

# %%
df["투자의견"] = df["투자의견"].replace("N/A", np.nan)
df["매수매도"] = df["투자의견"].str.replace("[0-9.]","")
df["투자의견"] = df["투자의견"].str.replace("[^0-9.]","").astype(float)
df["투자의견"]
# Out:
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/3294772075.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["매수매도"] = df["투자의견"].str.replace("[0-9.]","")
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/3294772075.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["투자의견"] = df["투자의견"].str.replace("[^0-9.]","").astype(float)
# 0     NaN
# 1     NaN
# 2     NaN
# 3     4.0
# 4     NaN
#      ...
# 92    NaN
# 93    NaN
# 94    NaN
# 95    NaN
# 96    4.0
# Name: 투자의견, Length: 97, dtype: float64

# %%
# df["투자의견"].astype(float)

# %%
# 투자의견의 수치만 pd.to_numeric 으로 숫자로 만들기
df["투자의견"] = pd.to_numeric(df["투자의견"])
df["투자의견"]
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     4.0
# 4     NaN
#      ...
# 92    NaN
# 93    NaN
# 94    NaN
# 95    NaN
# 96    4.0
# Name: 투자의견, Length: 97, dtype: float64

# %%
# 투자의견 컬럼만 가져와서 describe로 기술통계 값을 봅니다.
df["투자의견"].describe()
# Out:
# count    31.000000
# mean      3.956129
# std       0.183933
# min       3.000000
# 25%       4.000000
# 50%       4.000000
# 75%       4.000000
# max       4.000000
# Name: 투자의견, dtype: float64

# %% [markdown]
# ### 데이터 타입 변경하기
# * "동일업종 PER 컬럼"에서 "배" 문자를 제거하고 수치 변수로 변환해 주세요.
# * 전처리 결괏값은 df["동일업종 PER(배)"]라는 컬럼에 담아주세요

# %%
df["동일업종 PER"] = df["동일업종 PER"].str.replace("[^0-9]", "").astype(float)
# Out:
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/43766664.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["동일업종 PER"] = df["동일업종 PER"].str.replace("[^0-9]", "").astype(float)

# %%
df["동일업종 PER"]
# Out:
# 0     1020.0
# 1     2422.0
# 2     1020.0
# 3     5411.0
# 4     3469.0
#        ...
# 92    3883.0
# 93    2422.0
# 94    1286.0
# 95    3469.0
# 96    1040.0
# Name: 동일업종 PER, Length: 97, dtype: float64

# %%
# "동일업종 PER 컬럼"에서 "배" 문자를 제거하고 수치 변수로 변환해 주세요.

# %%
# str.replace, astype를 이용하면 쉽게 해결할 수 있습니다.

# %% [markdown]
# ## filter와 melt로 여러 컬럼 전처리하기
#
# ### PER와 EPS
#
# #### PER 주가수익비율
#
# * "이 주식은 비싼가, 주식시장이 거품인가" 판단하는 시금석
# * PER = 주식가격 / 주당순이익(EPS)
#
# 물건을 살 때 값을 얼마나 줘야 좋은 건지 판단할 기준은 수없이 많다. 내게 얼마나 절실한가. 이 물건이 얼마나 유용하고 값어치가 있나. 혹은 어느 정도나 오래 사용할 수 있나. 물건에 대한 다른 사람들의 평판은 어떤가. 물건이 내게 주는 수익은 어느 정도인가…. 생각해보면 쉽게 떠오르는 이런저런 이유들은 어려운 주식투자나, 투자결정에도 그대로 적용된다.
#
# 이런 점에서 흔히 투자자들 사이에서 `퍼(PER)`로 불리는 **주가수익비율(Price earning ratio, 이하 PER)**은 어떤 회사의 주식가치, 더 나아가 전체 주식시장의 가치가 고평가 됐는지 가늠할 수 있는 유용한 잣대다. **PER은 현재 시장에서 매매되는 특정회사의 주식가격을 주당순이익으로 나눈 값을 말한다.** 한 주에 만 원하는 회사주식이 1년에 주당 1000원의 순이익을 낸다면? PER은 10이 된다. 이 수치가 회사의 가치를 어떻게 반영한다는 얘기일까?
#
# * 출처 [네이버 지식백과]주가수익비율(PER) - "이 주식은 비싼가, 주식시장이 거품인가" 판단하는 시금석 (금융사전, 김태근)
# * https://terms.naver.com/entry.nhn?docId=3571127&cid=58781&categoryId=58781
#
# #### EPS 주당순이익
#
# * EPS =  순이익(당기순이익) / 그 기업이 발행한 총 주식수
#
# 주당순이익(EPS)은 기업이 벌어들인 순이익(당기순이익)을 그 기업이 발행한 총 주식수로 나눈 값으로, 1주당 이익을 얼마나 창출하였느냐를 나타내는 지표이다. 즉 해당 회사가 1년간 올린 수익에 대한 주주의 몫을 나타내는 지표라 할 수 있다. 또한 주당순이익은 주가수익비율(PER)계산의 기초가 되기도 한다.
#
# EPS가 높을수록 주식의 투자 가치는 높다고 볼 수 있으며, 그만큼 해당 회사의 경영실적이 양호하다는 뜻이다. 따라서 배당 여력도 많으므로 주가에 긍정적인 영향을 미친다.
#
# EPS는 당기순이익 규모가 늘면 높아지게 되고, 전환사채의 주식전환이나 증자로 주식수가 많아지면 낮아지게 된다. 특히 최근 주식시장의 패턴이 기업의 수익성을 중시하는 쪽으로 바뀌면서 EPS의 크기가 중요시되고 있다.
#
# * 출처 : [네이버 지식백과] 주당순이익(EPS) (시사상식사전, pmg 지식엔진연구소)
# * https://terms.naver.com/entry.nhn?docId=74510&cid=43667&categoryId=43667

# %% [markdown]
# ### filter 를 사용해 특정 텍스트가 들어가는 컬럼 찾기
# * [정규 표현식 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EC%A0%95%EA%B7%9C_%ED%91%9C%ED%98%84%EC%8B%9D)

# %%
# df.filter(regex=)를 통해 "PERlEPS" 가 들어가는 컬럼만 가져옵니다.
# 특정 컬럼을 가져오고 종목코드를 추가해 줍니다.
df_per_eps = df.filter(regex="^PERlEPS").copy()
df_per_eps["종목코드"] = df["종목코드"]
df_per_eps
# Out:
#       PERlEPS(2021.09) PERlEPS(2020.12)    종목코드
# 0      30.51배  l  926원              NaN  006110
# 1      N/A  l  -1,064원              NaN  262260
# 2        N/A  l  -184원              NaN  001780
# 3   109.17배  l  3,718원              NaN  247540
# 4      39.09배  l  353원              NaN  053080
# ..                 ...              ...     ...
# 92       N/A  l  -366원              NaN  079810
# 93     20.60배  l  482원              NaN  251630
# 94       N/A  l  -128원              NaN  267320
# 95     49.58배  l  236원              NaN  051490
# 96   21.49배  l  1,992원              NaN  178920
#
# [97 rows x 3 columns]

# %% [markdown]
# ### melt로 tidy data 만들기
#
# <img src="https://pandas.pydata.org/docs/_images/reshaping_melt.png" width="600">
#
# * https://pandas.pydata.org/docs/user_guide/reshaping.html#reshaping-by-melt
# * [Tidy Data 란?](https://vita.had.co.nz/papers/tidy-data.pdf)

# %%
# melt를 통해 종목코드를 녹여냅니다.
df_per_eps_melt = df_per_eps.melt(id_vars="종목코드")

# %%
# 종목코드별로 value_counts를 통해  PERlEPS 행이 몇 개인지 봅니다.
df_per_eps_melt["종목코드"].value_counts()
# Out:
# 006110    2
# 093230    2
# 006400    2
# 001570    2
# 137940    2
#          ..
# 278280    2
# 011790    2
# 054210    2
# 036830    2
# 178920    2
# Name: 종목코드, Length: 97, dtype: int64

# %% [markdown]
# ### 결측치 데이터 제거
# <img src="https://pandas.pydata.org/docs/_images/03_subset_rows.svg">

# %%
# PERlEPS 데이터프레임에서 결측치 데이터 제거
# 여기에서 기간별로 생긴 행은 이전 실습에서 concat으로 데이터를 합칠 때 
# 컬럼의 이름이 다르면 새로운 컬럼으로 생성하기 때문입니다.
df_pe = df_per_eps_melt.dropna()
df_pe
# Out:
#        종목코드          variable               value
# 0    006110  PERlEPS(2021.09)     30.51배  l  926원
# 1    262260  PERlEPS(2021.09)     N/A  l  -1,064원
# 2    001780  PERlEPS(2021.09)       N/A  l  -184원
# 3    247540  PERlEPS(2021.09)  109.17배  l  3,718원
# 4    053080  PERlEPS(2021.09)     39.09배  l  353원
# ..      ...               ...                 ...
# 104  299030  PERlEPS(2020.12)     N/A  l  -5,724원
# 107  382480  PERlEPS(2020.12)         N/A  l  N/A
# 120  348370  PERlEPS(2020.12)   1,957.69배  l  52원
# 123  361610  PERlEPS(2020.12)   93.36배  l  1,521원
# 185  382840  PERlEPS(2020.12)         N/A  l  N/A
#
# [97 rows x 3 columns]

# %%
# variable 컬럼명을 rename을 통해 "PERlEPS"로 변경합니다.
# df_pe
df_pe = df_pe.rename(columns={"variable":"PERlEPS"})
df_pe
# Out:
#        종목코드           PERlEPS               value
# 0    006110  PERlEPS(2021.09)     30.51배  l  926원
# 1    262260  PERlEPS(2021.09)     N/A  l  -1,064원
# 2    001780  PERlEPS(2021.09)       N/A  l  -184원
# 3    247540  PERlEPS(2021.09)  109.17배  l  3,718원
# 4    053080  PERlEPS(2021.09)     39.09배  l  353원
# ..      ...               ...                 ...
# 104  299030  PERlEPS(2020.12)     N/A  l  -5,724원
# 107  382480  PERlEPS(2020.12)         N/A  l  N/A
# 120  348370  PERlEPS(2020.12)   1,957.69배  l  52원
# 123  361610  PERlEPS(2020.12)   93.36배  l  1,521원
# 185  382840  PERlEPS(2020.12)         N/A  l  N/A
#
# [97 rows x 3 columns]

# %%
# df_pe에서 PER, EPS 컬럼을 따로 생성합니다.
df_pe["PER"] = df_pe["value"].str.split("  l  ",expand=True)[0]
df_pe["EPS"] = df_pe["value"].str.split("  l  ",expand=True)[1]

# %%
# PER, EPS 컬럼의 N/A 값을 결측치로 만듭니다.

df_pe["PER"] = df_pe["PER"].replace("N/A", np.nan)
df_pe["EPS"] = df_pe["EPS"].replace("N/A", np.nan)

# %%
#  PER, EPS 값 중 둘 다 결측치는 notnull 혹은 isnull을 사용해 제거합니다.
df_pe = df_pe[df_pe["PER"].notnull() | df_pe["EPS"].notnull()].copy()
df_pe
# Out:
#        종목코드           PERlEPS               value        PER      EPS
# 0    006110  PERlEPS(2021.09)     30.51배  l  926원     30.51배     926원
# 1    262260  PERlEPS(2021.09)     N/A  l  -1,064원        NaN  -1,064원
# 2    001780  PERlEPS(2021.09)       N/A  l  -184원        NaN    -184원
# 3    247540  PERlEPS(2021.09)  109.17배  l  3,718원    109.17배   3,718원
# 4    053080  PERlEPS(2021.09)     39.09배  l  353원     39.09배     353원
# ..      ...               ...                 ...        ...      ...
# 95   051490  PERlEPS(2021.09)     49.58배  l  236원     49.58배     236원
# 96   178920  PERlEPS(2021.09)   21.49배  l  1,992원     21.49배   1,992원
# 104  299030  PERlEPS(2020.12)     N/A  l  -5,724원        NaN  -5,724원
# 120  348370  PERlEPS(2020.12)   1,957.69배  l  52원  1,957.69배      52원
# 123  361610  PERlEPS(2020.12)   93.36배  l  1,521원     93.36배   1,521원
#
# [95 rows x 5 columns]

# %%
# PER(배) 컬럼을 만들고 수치데이터 형태로 변환합니다.
# df_pe["PER(배)"] = df_pe["PER"].str.replace("[^0-9.]", "").astype(float)
df_pe["PER(배)"] = df_pe["PER"]
df_pe["PER(배)"]
# Out:
# 0         30.51배
# 1            NaN
# 2            NaN
# 3        109.17배
# 4         39.09배
#          ...
# 95        49.58배
# 96        21.49배
# 104          NaN
# 120    1,957.69배
# 123       93.36배
# Name: PER(배), Length: 95, dtype: object

# %%
# EPS(원) 컬럼을 만들고 수치데이터 형태로 변환합니다.
df_pe["EPS(원)"] = df_pe["EPS"].str.replace("원|,", "").astype(float)
# Out:
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/1237661151.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_pe["EPS(원)"] = df_pe["EPS"].str.replace("원|,", "").astype(float)

# %%
df_pe["EPS(원)"]
# Out:
# 0       926.0
# 1     -1064.0
# 2      -184.0
# 3      3718.0
# 4       353.0
#         ...
# 95      236.0
# 96     1992.0
# 104   -5724.0
# 120      52.0
# 123    1521.0
# Name: EPS(원), Length: 95, dtype: float64

# %%
# 필요한 컬럼만 따로 가져옵니다.
df_pe = df_pe[["종목코드", "PERlEPS", "PER(배)", "EPS(원)"]].copy()
df_pe
# Out:
#        종목코드           PERlEPS     PER(배)  EPS(원)
# 0    006110  PERlEPS(2021.09)     30.51배   926.0
# 1    262260  PERlEPS(2021.09)        NaN -1064.0
# 2    001780  PERlEPS(2021.09)        NaN  -184.0
# 3    247540  PERlEPS(2021.09)    109.17배  3718.0
# 4    053080  PERlEPS(2021.09)     39.09배   353.0
# ..      ...               ...        ...     ...
# 95   051490  PERlEPS(2021.09)     49.58배   236.0
# 96   178920  PERlEPS(2021.09)     21.49배  1992.0
# 104  299030  PERlEPS(2020.12)        NaN -5724.0
# 120  348370  PERlEPS(2020.12)  1,957.69배    52.0
# 123  361610  PERlEPS(2020.12)     93.36배  1521.0
#
# [95 rows x 4 columns]

# %% [markdown]
# ### 중복 데이터 확인

# %%
df_pe
# Out:
#        종목코드           PERlEPS     PER(배)  EPS(원)
# 0    006110  PERlEPS(2021.09)     30.51배   926.0
# 1    262260  PERlEPS(2021.09)        NaN -1064.0
# 2    001780  PERlEPS(2021.09)        NaN  -184.0
# 3    247540  PERlEPS(2021.09)    109.17배  3718.0
# 4    053080  PERlEPS(2021.09)     39.09배   353.0
# ..      ...               ...        ...     ...
# 95   051490  PERlEPS(2021.09)     49.58배   236.0
# 96   178920  PERlEPS(2021.09)     21.49배  1992.0
# 104  299030  PERlEPS(2020.12)        NaN -5724.0
# 120  348370  PERlEPS(2020.12)  1,957.69배    52.0
# 123  361610  PERlEPS(2020.12)     93.36배  1521.0
#
# [95 rows x 4 columns]

# %%
# "종목코드"기준으로 중복된 데이터가 있는지 찾습니다.
df_pe[df_pe.duplicated("종목코드")]
# Out:
# Empty DataFrame
# Columns: [종목코드, PERlEPS, PER(배), EPS(원)]
# Index: []

# %%
# 만약 중복데이터가 있다면 다음과 같은 방법으로 제거합니다.
# 추출했던 원래 데이터프레임 df와 다시 merge 로 합치기 위해 
# drop_duplicates 를 사용해 종목코드가 중복되는 행은 제거합니다.
# "종목코드", "PERlEPS" 로 정렬을 하고 
# drop_duplicates 로 제거시 keep="first" 로 위에 있는 데이터를 남깁니다.
df_pe = df_pe.sort_values(["종목코드","PERlEPS"])
df_pe.drop_duplicates()
# Out:
#        종목코드           PERlEPS     PER(배)   EPS(원)
# 63   001390  PERlEPS(2021.09)      3.94배   6798.0
# 56   001530  PERlEPS(2021.09)     16.47배  13932.0
# 70   001570  PERlEPS(2021.09)    231.36배     22.0
# 2    001780  PERlEPS(2021.09)        NaN   -184.0
# 87   002710  PERlEPS(2021.09)     22.12배    452.0
# ..      ...               ...        ...      ...
# 18   336370  PERlEPS(2021.09)        NaN   -254.0
# 9    340930  PERlEPS(2021.09)        NaN   -247.0
# 120  348370  PERlEPS(2020.12)  1,957.69배     52.0
# 38   357780  PERlEPS(2021.09)     13.64배  17888.0
# 123  361610  PERlEPS(2020.12)     93.36배   1521.0
#
# [95 rows x 4 columns]

# %%
df_pe["종목코드"].value_counts().unique()
# Out:
# array([1], dtype=int64)

# %%
# 종목코드값 기준으로 중복데이터를 확인합니다.

# %% [markdown]
# ### PBRlBPS 전처리
#
#
# #### PBR(주가순자산비율, price-to-book ratio, P/B ratio)
#
# * PBR = 주가/BPS(주당순자산가치)
# * 주가는 그 회사의 종합적인 평가이므로 주주 소유분을 초과한 부분은 모두 그 회사의 잠재적인 프리미엄이 되기 때문에 **경영의 종합력이 뛰어나면 뛰어날수록 배율이 높아진다**고 할 수 있다. 일반적으로 이 지표는 PER과 함께 사용되는데, 이는 주가순자산배율이 그 회사를 정적인 상태 즉 스토크(stock)면에서 보고 있는데 반하여 주가수익률은 동적인 상태 즉 플로(flow)면에서 보고 있으므로 두 가지 지표가 서로 보완관계에 있다.
#
# * 다만 이 주가 순자산배율에도 **주주소유분이 장부가격에 의해 계산되고 있어 반드시 정확하다고 할 수 없고 또 그 계산기준이 전기의 결산기가 된다는 등의 난점이 있다.**
# * 출처 : [주가순자산비율 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EC%A3%BC%EA%B0%80%EC%88%9C%EC%9E%90%EC%82%B0%EB%B9%84%EC%9C%A8)
#
# #### BPS(주당순자산가치, Book-value Per Share)
#
# * 주당순자산가치 = 기업의 순자산/ 발행 주식수
# * 주당순자산가치는, '청산가치' 라고도 불린다. 그 이유는 현재 시점에서 기업의 활동을 중단시키고 그 부를 모든 주주들에게 나눠줄 경우 한주당 얼마씩이 돌아가는가를 나타내는 수치이기 때문이다. 보통 주당순자산가치라는 말은 잘 쓰지 않고 BPS라고 하므로 이하 BPS로 쓴다.
#
# * BPS가 높다는 것은 자기자본의 비중이 크거나 회사 가치가 높다는 것을 나타낸다. BPS에는 주가 정보가 고려되어 있지 않으므로, 이 회사의 주가가 자산 가치에 비해 얼마나 저평가 혹은 고평가되어 있는지 판단하기 위해 PBR이라는 값을 사용한다.
#
# * PBR 값은 BPS 값으로 현재 주가를 나눈 것이다. BPS가 1만원인 위 사례에서 주가가 5,000원이라면 PBR은 0.5가 되고, 주가가 20,000원이라면 PBR은 2가 된다. 즉 전자의 경우 주가는 실제의 자산에 비해 저평가되어 되어 있는 것이고, 후자의 경우 주가는 실제 자산에 비해 고평가 되어 있는 것이다.
#
# * 출처 : [주당순자산가치 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EC%A3%BC%EB%8B%B9%EC%88%9C%EC%9E%90%EC%82%B0%EA%B0%80%EC%B9%98)

# %%
# filter를 사용해 PBRlBPS 컬럼 가져옵니다.
# 종목코드 추가합니다.
df_pbr_bps = df.filter(regex="PBRlBPS").copy()
df_pbr_bps["종목코드"] = df["종목코드"]
df_pbr_bps
# Out:
#      PBRlBPS (2021.09) PBRlBPS (2020.12)    종목코드
# 0    2.61배  l  10,809원               NaN  006110
# 1     4.93배  l  7,752원               NaN  262260
# 2     1.51배  l  2,637원               NaN  001780
# 3   17.28배  l  23,486원               NaN  247540
# 4    1.28배  l  10,772원               NaN  053080
# ..                 ...               ...     ...
# 92    3.39배  l  1,607원               NaN  079810
# 93    1.53배  l  6,505원               NaN  251630
# 94      8.14배  l  617원               NaN  267320
# 95    1.90배  l  6,165원               NaN  051490
# 96   4.06배  l  10,552원               NaN  178920
#
# [97 rows x 3 columns]

# %%
# melt로 tidy data 만듭니다.
df_pbr_bps_melt = df_pbr_bps.melt(id_vars="종목코드").copy()
df_pbr_bps_melt
# Out:
#        종목코드           variable               value
# 0    006110  PBRlBPS (2021.09)   2.61배  l  10,809원
# 1    262260  PBRlBPS (2021.09)    4.93배  l  7,752원
# 2    001780  PBRlBPS (2021.09)    1.51배  l  2,637원
# 3    247540  PBRlBPS (2021.09)  17.28배  l  23,486원
# 4    053080  PBRlBPS (2021.09)   1.28배  l  10,772원
# ..      ...                ...                 ...
# 189  079810  PBRlBPS (2020.12)                 NaN
# 190  251630  PBRlBPS (2020.12)                 NaN
# 191  267320  PBRlBPS (2020.12)                 NaN
# 192  051490  PBRlBPS (2020.12)                 NaN
# 193  178920  PBRlBPS (2020.12)                 NaN
#
# [194 rows x 3 columns]

# %%
# 결측치를 제거합니다.
df_pb = df_pbr_bps_melt.dropna()
df_pb
# Out:
#        종목코드           variable               value
# 0    006110  PBRlBPS (2021.09)   2.61배  l  10,809원
# 1    262260  PBRlBPS (2021.09)    4.93배  l  7,752원
# 2    001780  PBRlBPS (2021.09)    1.51배  l  2,637원
# 3    247540  PBRlBPS (2021.09)  17.28배  l  23,486원
# 4    053080  PBRlBPS (2021.09)   1.28배  l  10,772원
# ..      ...                ...                 ...
# 104  299030  PBRlBPS (2020.12)    7.92배  l  7,452원
# 107  382480  PBRlBPS (2020.12)         N/A  l  N/A
# 120  348370  PBRlBPS (2020.12)   9.45배  l  10,772원
# 123  361610  PBRlBPS (2020.12)   4.53배  l  31,331원
# 185  382840  PBRlBPS (2020.12)         N/A  l  N/A
#
# [97 rows x 3 columns]

# %%
# variable 컬럼명을 "PBRlBPS"로 변경합니다.
df_pb = df_pb.rename(columns={"variable":"PBRlBPS"})
df_pb
# Out:
#        종목코드            PBRlBPS               value
# 0    006110  PBRlBPS (2021.09)   2.61배  l  10,809원
# 1    262260  PBRlBPS (2021.09)    4.93배  l  7,752원
# 2    001780  PBRlBPS (2021.09)    1.51배  l  2,637원
# 3    247540  PBRlBPS (2021.09)  17.28배  l  23,486원
# 4    053080  PBRlBPS (2021.09)   1.28배  l  10,772원
# ..      ...                ...                 ...
# 104  299030  PBRlBPS (2020.12)    7.92배  l  7,452원
# 107  382480  PBRlBPS (2020.12)         N/A  l  N/A
# 120  348370  PBRlBPS (2020.12)   9.45배  l  10,772원
# 123  361610  PBRlBPS (2020.12)   4.53배  l  31,331원
# 185  382840  PBRlBPS (2020.12)         N/A  l  N/A
#
# [97 rows x 3 columns]

# %%
# PBR, BPS 컬럼을 만듭니다.
df_pb["PBR"] = df_pb["value"].str.split("  l  ", expand=True)[0]
df_pb["BPS"] = df_pb["value"].str.split("  l  ", expand=True)[1]

# %%
# N/A 값(문자) np.nan(결측치)로 변환합니다.
df_pb["PBR"] = df_pb["PBR"].replace("N/A", np.nan)
df_pb["BPS"] = df_pb["BPS"].replace("N/A", np.nan)

# %%
# PBR(배), BPS(원) 컬럼을 만듭니다.
# df_pb["PBR(배)"]
# df_pb["BPS(원)"]
df_pb["PBR(배)"] = df_pb["PBR"].str.replace("배", "").astype(float)
df_pb["BPS(원)"] = df_pb["BPS"].str.replace("원|,", "").astype(float)
# Out:
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/396379228.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_pb["BPS(원)"] = df_pb["BPS"].str.replace("원|,", "").astype(float)

# %%
# 종목코드 기준 value_counts 를 구해 중복값이 있는지 확인합니다.
df_pb
# Out:
#        종목코드            PBRlBPS               value     PBR      BPS  PBR(배)  \
# 0    006110  PBRlBPS (2021.09)   2.61배  l  10,809원   2.61배  10,809원    2.61
# 1    262260  PBRlBPS (2021.09)    4.93배  l  7,752원   4.93배   7,752원    4.93
# 2    001780  PBRlBPS (2021.09)    1.51배  l  2,637원   1.51배   2,637원    1.51
# 3    247540  PBRlBPS (2021.09)  17.28배  l  23,486원  17.28배  23,486원   17.28
# 4    053080  PBRlBPS (2021.09)   1.28배  l  10,772원   1.28배  10,772원    1.28
# ..      ...                ...                 ...     ...      ...     ...
# 104  299030  PBRlBPS (2020.12)    7.92배  l  7,452원   7.92배   7,452원    7.92
# 107  382480  PBRlBPS (2020.12)         N/A  l  N/A     NaN      NaN     NaN
# 120  348370  PBRlBPS (2020.12)   9.45배  l  10,772원   9.45배  10,772원    9.45
# 123  361610  PBRlBPS (2020.12)   4.53배  l  31,331원   4.53배  31,331원    4.53
# 185  382840  PBRlBPS (2020.12)         N/A  l  N/A     NaN      NaN     NaN
#
#       BPS(원)
# 0    10809.0
# 1     7752.0
# 2     2637.0
# 3    23486.0
# 4    10772.0
# ..       ...
# 104   7452.0
# 107      NaN
# 120  10772.0
# 123  31331.0
# 185      NaN
#
# [97 rows x 7 columns]

# %%
# "종목코드","PBRlBPS" 로 중복값이 있는지 확인합니다.
# 만약 중복값이 있다면 drop_duplicates 로 삭제합니다.
df_pb["종목코드"].value_counts().unique()
# Out:
# array([1], dtype=int64)

# %%
# 사용할 컬럼만 따로 지정해줍니다.
# "종목코드", "PBRlBPS", "PBR(배)", "BPS(원)"
df_pb = df_pb[["종목코드", "PBRlBPS", "PBR(배)", "BPS(원)"]]
df_pb
# Out:
#        종목코드            PBRlBPS  PBR(배)   BPS(원)
# 0    006110  PBRlBPS (2021.09)    2.61  10809.0
# 1    262260  PBRlBPS (2021.09)    4.93   7752.0
# 2    001780  PBRlBPS (2021.09)    1.51   2637.0
# 3    247540  PBRlBPS (2021.09)   17.28  23486.0
# 4    053080  PBRlBPS (2021.09)    1.28  10772.0
# ..      ...                ...     ...      ...
# 104  299030  PBRlBPS (2020.12)    7.92   7452.0
# 107  382480  PBRlBPS (2020.12)     NaN      NaN
# 120  348370  PBRlBPS (2020.12)    9.45  10772.0
# 123  361610  PBRlBPS (2020.12)    4.53  31331.0
# 185  382840  PBRlBPS (2020.12)     NaN      NaN
#
# [97 rows x 4 columns]

# %% [markdown]
# ### 배당 수익률 전처리

# %%
# PER|EPS 전처리와 마찬가리로 배당수익률 데이터를 전처리 합니다.
# df.filter(regex=) 로 배당수익률이 들어가는 컬럼만 찾고 종목코드를 추가 합니다.
# df_income
df_income = df.filter(regex="배당수익률").copy()
df_income["종목코드"] = df["종목코드"]
df_income
# Out:
#    배당수익률l2021.12    종목코드
# 0            NaN  006110
# 1            NaN  262260
# 2            NaN  001780
# 3          0.23%  247540
# 4            NaN  053080
# ..           ...     ...
# 92           NaN  079810
# 93         1.01%  251630
# 94           NaN  267320
# 95           NaN  051490
# 96           NaN  178920
#
# [97 rows x 2 columns]

# %%
# 추후 병합을 위해 데이터프레임에 종목코드를 추가합니다.
df_income["종목코드"] = df["종목코드"]
df_income
# Out:
#    배당수익률l2021.12    종목코드
# 0            NaN  006110
# 1            NaN  262260
# 2            NaN  001780
# 3          0.23%  247540
# 4            NaN  053080
# ..           ...     ...
# 92           NaN  079810
# 93         1.01%  251630
# 94           NaN  267320
# 95           NaN  051490
# 96           NaN  178920
#
# [97 rows x 2 columns]

# %%
# melt 로 여러 컬럼의 종목코드를 행으로 녹이고 결측치를 dropna 로 제거합니다.
df_in = df_income.melt(id_vars="종목코드").copy()
df_in = df_in.dropna()
df_in
# Out:
#       종목코드       variable  value
# 3   247540  배당수익률l2021.12  0.23%
# 5   282880  배당수익률l2021.12  0.30%
# 8   086520  배당수익률l2021.12  0.49%
# 19  084850  배당수익률l2021.12  0.50%
# 30  278280  배당수익률l2021.12  0.10%
# 63  001390  배당수익률l2021.12  1.87%
# 93  251630  배당수익률l2021.12  1.01%

# %%
# 컬럼명을 "종목코드", "배당수익률기간", "배당수익률" 로 변경합니다.
df_in.columns = ["종목코드", "배당수익률기간", "배당수익률"]
df_in
# Out:
#       종목코드        배당수익률기간  배당수익률
# 3   247540  배당수익률l2021.12  0.23%
# 5   282880  배당수익률l2021.12  0.30%
# 8   086520  배당수익률l2021.12  0.49%
# 19  084850  배당수익률l2021.12  0.50%
# 30  278280  배당수익률l2021.12  0.10%
# 63  001390  배당수익률l2021.12  1.87%
# 93  251630  배당수익률l2021.12  1.01%

# %%
# 배당수익률% 컬럼을 만들어 전처리 합니다.

df_in["배당수익률%"] = df_in["배당수익률"].str.replace("%","").astype(float)

# %%
# 종목코드가 종목당 2개 이상 있는 값이 있는지 확인합니다.
# 2개 이상 있다면 merge 에서 어떤 값을 사용할지 고려해야 합니다.
df_in["종목코드"].value_counts().unique()
# Out:
# array([1], dtype=int64)

# %%
# 전처리가 끝난 배당수익률 컬럼은 제거합니다.
del df_in["배당수익률"]
df_in
# Out:
#       종목코드        배당수익률기간  배당수익률%
# 3   247540  배당수익률l2021.12    0.23
# 5   282880  배당수익률l2021.12    0.30
# 8   086520  배당수익률l2021.12    0.49
# 19  084850  배당수익률l2021.12    0.50
# 30  278280  배당수익률l2021.12    0.10
# 63  001390  배당수익률l2021.12    1.87
# 93  251630  배당수익률l2021.12    1.01

# %%
df_in
# Out:
#       종목코드        배당수익률기간  배당수익률%
# 3   247540  배당수익률l2021.12    0.23
# 5   282880  배당수익률l2021.12    0.30
# 8   086520  배당수익률l2021.12    0.49
# 19  084850  배당수익률l2021.12    0.50
# 30  278280  배당수익률l2021.12    0.10
# 63  001390  배당수익률l2021.12    1.87
# 93  251630  배당수익률l2021.12    1.01

# %% [markdown]
# ## merge 로 기존 데이터와 병합하기
#
# <img src="https://pandas.pydata.org/docs/_images/08_merge_left.svg">
#
# * concat과 merge의 차이
#     * concat :
#         * axis=0 행을 기준으로 위아래로 **같은 컬럼끼리** 값을 이어 붙여 **새로운 행을 만듦**
#         * axis=1 컬럼을 기준으로 **인덱스가 같은 값**을 옆으로 붙여 **새로운 컬럼을 만듦**
#     * merge :
#         * index 혹은 특정 컬럼 값을 기준으로 두 개의 데이터프레임을 연결
#
# <img src="https://www.dofactory.com/img/sql/sql-joins.png">
#
# * 이미지 출처 : https://www.dofactory.com/sql/join

# %%
df.shape
# Out:
# (97, 51)

# %%
# merge로 병합합니다.
# df와 df_pe를 병합니다. merge 전후 행과 열의 수를 확인해서 제대로 병합이 되었는지 확인합니다.
# df_merge_pe 에 할당합니다.
df_merge_pe = df.merge(df_pe, left_on="종목코드", right_on="종목코드", how="left")
df_merge_pe.head(1)
# Out:
#      종목명     종목명.1      현재가     전일비     등락률     매수호가     매도호가       거래량  \
# 0  삼아알미늄  테마 편입 사유  28050.0  1100.0  +4.08%  28150.0  28200.0  470144.0
#
#       거래대금     전일거래량        조회일자 종목명_전처리    종목코드  매출액  영업이익  당기순이익  영업이익률  \
# 0  13046.0  133848.0  2022-01-25   삼아알미늄  006110  NaN   NaN    NaN    NaN
#
#    순이익률  EPS(원)_x  PER(배)_x  BPS(원)  PBR(배)       시가총액    시가총액순위     상장주식수  \
# 0   NaN       NaN       NaN     NaN     NaN  3,108  억원  코스피 458위  11000000
#
#       액면가l매매단위  외국인한도주식수(A)  외국인보유주식수(B) 외국인소진율(B/A)    투자의견l목표주가  \
# 0  500원  l  1주     11000000      3653946      33.22%  N/A  l  N/A
#
#            52주최고l최저 PERlEPS(2021.09)    추정PERlEPS  PBRlBPS (2021.09)  \
# 0  45,600  l  9,150  30.51배  l  926원  N/A  l  N/A  2.61배  l  10,809원
#
#    동일업종 PER 동일업종 등락률 배당수익률l2021.12 PERlEPS(2020.12) PBRlBPS (2020.12) 코스피/코스닥  \
# 0    1020.0   -1.79%           NaN              NaN               NaN     코스피
#
#    시가총액(억원)  시가총액순위(전처리)  52주최고  52주최저  52주차액   52주차액비율   현재-최고가  현재/최고가비율  \
# 0      3108          458  45600   9150  36450  4.983607 -17550.0  0.615132
#
#    투자의견  목표주가 매수매도           PERlEPS PER(배)_y  EPS(원)_y
# 0   NaN   NaN  NaN  PERlEPS(2021.09)   30.51배     926.0

# %%
df_merge_pe.shape
# Out:
# (97, 54)

# %%
# 위에서 병합한 데이터(df_merge_pe)에 PBRlBPS(df_pb) 데이터도 병합해 줍니다.
df_merge_pb = df_merge_pe.merge(df_pb, on="종목코드", how="left")
df_merge_pb.head(1)
# Out:
#      종목명     종목명.1      현재가     전일비     등락률     매수호가     매도호가       거래량  \
# 0  삼아알미늄  테마 편입 사유  28050.0  1100.0  +4.08%  28150.0  28200.0  470144.0
#
#       거래대금     전일거래량        조회일자 종목명_전처리    종목코드  매출액  영업이익  당기순이익  영업이익률  \
# 0  13046.0  133848.0  2022-01-25   삼아알미늄  006110  NaN   NaN    NaN    NaN
#
#    순이익률  EPS(원)_x  PER(배)_x  BPS(원)_x  PBR(배)_x       시가총액    시가총액순위  \
# 0   NaN       NaN       NaN       NaN       NaN  3,108  억원  코스피 458위
#
#       상장주식수     액면가l매매단위  외국인한도주식수(A)  외국인보유주식수(B) 외국인소진율(B/A)    투자의견l목표주가  \
# 0  11000000  500원  l  1주     11000000      3653946      33.22%  N/A  l  N/A
#
#            52주최고l최저 PERlEPS(2021.09)    추정PERlEPS  PBRlBPS (2021.09)  \
# 0  45,600  l  9,150  30.51배  l  926원  N/A  l  N/A  2.61배  l  10,809원
#
#    동일업종 PER 동일업종 등락률 배당수익률l2021.12 PERlEPS(2020.12) PBRlBPS (2020.12) 코스피/코스닥  \
# 0    1020.0   -1.79%           NaN              NaN               NaN     코스피
#
#    시가총액(억원)  시가총액순위(전처리)  52주최고  52주최저  52주차액   52주차액비율   현재-최고가  현재/최고가비율  \
# 0      3108          458  45600   9150  36450  4.983607 -17550.0  0.615132
#
#    투자의견  목표주가 매수매도           PERlEPS PER(배)_y  EPS(원)_y            PBRlBPS  \
# 0   NaN   NaN  NaN  PERlEPS(2021.09)   30.51배     926.0  PBRlBPS (2021.09)
#
#    PBR(배)_y  BPS(원)_y
# 0      2.61   10809.0

# %%
df_merge_pb.shape
# Out:
# (97, 57)

# %%
# 위에서 병합한 데이터(df_merge_pb)에 배당수익률(df_in) 데이터도 병합해 줍니다.
# df_final 이라는 변수에 담습니다.
df_final = df_merge_pb.merge(df_in, how="left")
df_final.shape
# Out:
# (97, 59)

# %%
df_final.head(1)
# Out:
#      종목명     종목명.1      현재가     전일비     등락률     매수호가     매도호가       거래량  \
# 0  삼아알미늄  테마 편입 사유  28050.0  1100.0  +4.08%  28150.0  28200.0  470144.0
#
#       거래대금     전일거래량        조회일자 종목명_전처리    종목코드  매출액  영업이익  당기순이익  영업이익률  \
# 0  13046.0  133848.0  2022-01-25   삼아알미늄  006110  NaN   NaN    NaN    NaN
#
#    순이익률  EPS(원)_x  PER(배)_x  BPS(원)_x  PBR(배)_x       시가총액    시가총액순위  \
# 0   NaN       NaN       NaN       NaN       NaN  3,108  억원  코스피 458위
#
#       상장주식수     액면가l매매단위  외국인한도주식수(A)  외국인보유주식수(B) 외국인소진율(B/A)    투자의견l목표주가  \
# 0  11000000  500원  l  1주     11000000      3653946      33.22%  N/A  l  N/A
#
#            52주최고l최저 PERlEPS(2021.09)    추정PERlEPS  PBRlBPS (2021.09)  \
# 0  45,600  l  9,150  30.51배  l  926원  N/A  l  N/A  2.61배  l  10,809원
#
#    동일업종 PER 동일업종 등락률 배당수익률l2021.12 PERlEPS(2020.12) PBRlBPS (2020.12) 코스피/코스닥  \
# 0    1020.0   -1.79%           NaN              NaN               NaN     코스피
#
#    시가총액(억원)  시가총액순위(전처리)  52주최고  52주최저  52주차액   52주차액비율   현재-최고가  현재/최고가비율  \
# 0      3108          458  45600   9150  36450  4.983607 -17550.0  0.615132
#
#    투자의견  목표주가 매수매도           PERlEPS PER(배)_y  EPS(원)_y            PBRlBPS  \
# 0   NaN   NaN  NaN  PERlEPS(2021.09)   30.51배     926.0  PBRlBPS (2021.09)
#
#    PBR(배)_y  BPS(원)_y 배당수익률기간  배당수익률%
# 0      2.61   10809.0     NaN     NaN

# %% [markdown]
# ## 사용하지 않는 컬럼 제거하기 drop

# %%
# l 구분자가 들어가는 컬럼명만 찾습니다.
del_cols = df_final.filter(regex="l").columns
del_cols
# Out:
# Index(['액면가l매매단위', '투자의견l목표주가', '52주최고l최저', 'PERlEPS(2021.09)', '추정PERlEPS',
#        'PBRlBPS (2021.09)', '배당수익률l2021.12', 'PERlEPS(2020.12)',
#        'PBRlBPS (2020.12)', 'PERlEPS', 'PBRlBPS'],
#       dtype='object')

# %%
# 위에서 찾은 컬럼명을 drop으로 삭제합니다.
df_final = df_final.drop(del_cols, axis=1).copy()
df_final
# Out:
#          종목명     종목명.1       현재가     전일비      등락률      매수호가      매도호가  \
# 0      삼아알미늄  테마 편입 사유   28050.0  1100.0   +4.08%   28150.0   28200.0
# 1     에이프로 *  테마 편입 사유   38050.0   800.0   +2.15%   38150.0   38200.0
# 2        알루코  테마 편입 사유    3970.0    60.0   +1.53%    4005.0    4010.0
# 3   에코프로비엠 *  테마 편입 사유  405400.0  5000.0   +1.25%  405000.0  405100.0
# 4     원방테크 *  테마 편입 사유   13800.0   150.0   +1.10%   13850.0   13900.0
# ..       ...       ...       ...     ...      ...       ...       ...
# 92    디이엔티 *  테마 편입 사유    5400.0   570.0   -9.55%    5380.0    5390.0
# 93    브이원텍 *  테마 편입 사유    9820.0  1230.0  -11.13%    9920.0    9940.0
# 94    나인테크 *  테마 편입 사유    4935.0   645.0  -11.56%    5030.0    5040.0
# 95   나라엠앤디 *  테마 편입 사유   11500.0  1550.0  -11.88%   11750.0   11800.0
# 96    PI첨단소재  테마 편입 사유   42700.0  6950.0  -14.00%   42750.0   42800.0
#
#            거래량      거래대금       전일거래량        조회일자 종목명_전처리    종목코드     매출액  \
# 0     470144.0   13046.0    133848.0  2022-01-25   삼아알미늄  006110     NaN
# 1     217060.0    8314.0   1656641.0  2022-01-25    에이프로  262260     NaN
# 2   23287831.0   97848.0   4906626.0  2022-01-25     알루코  001780     NaN
# 3     316436.0  129130.0    730341.0  2022-01-25  에코프로비엠  247540  4443.0
# 4     317443.0    4527.0    133205.0  2022-01-25    원방테크  053080     NaN
# ..         ...       ...         ...         ...     ...     ...     ...
# 92    283199.0    1566.0    410992.0  2022-01-25    디이엔티  079810     NaN
# 93    633024.0    6493.0    508320.0  2022-01-25    브이원텍  251630     NaN
# 94   3407339.0   17772.0  12491739.0  2022-01-25    나인테크  267320     NaN
# 95   1410582.0   17167.0   1864384.0  2022-01-25   나라엠앤디  051490     NaN
# 96    814638.0   35939.0    212149.0  2022-01-25  PI첨단소재  178920   718.0
#
#      영업이익  당기순이익  영업이익률   순이익률  EPS(원)_x  PER(배)_x  BPS(원)_x  PBR(배)_x  \
# 0     NaN    NaN    NaN    NaN       NaN       NaN       NaN       NaN
# 1     NaN    NaN    NaN    NaN       NaN       NaN    8236.0      4.52
# 2     NaN    NaN    NaN    NaN       NaN       NaN       NaN       NaN
# 3   403.0  332.0   9.08   7.46    1423.0    281.34   31929.0     12.54
# 4     NaN    NaN    NaN    NaN       NaN       NaN       NaN       NaN
# ..    ...    ...    ...    ...       ...       ...       ...       ...
# 92    NaN    NaN    NaN    NaN       NaN       NaN       NaN       NaN
# 93    NaN    NaN    NaN    NaN       NaN       NaN    6221.0      1.78
# 94    NaN    NaN    NaN    NaN       NaN       NaN       NaN       NaN
# 95    NaN    NaN    NaN    NaN       NaN       NaN       NaN       NaN
# 96  152.0  106.0  21.16  14.81     362.0    141.72   10882.0      4.71
#
#              시가총액     시가총액순위     상장주식수  외국인한도주식수(A)  외국인보유주식수(B) 외국인소진율(B/A)  \
# 0       3,108  억원   코스피 458위  11000000     11000000      3653946      33.22%
# 1       2,699  억원   코스닥 322위   7065942      7065942        53295       0.75%
# 2       3,565  억원   코스피 416위  89791232     89791232      1612229       1.80%
# 3   9조  3,030  억원     코스닥 2위  22919466     22919466      3613998      15.77%
# 4       1,794  억원   코스닥 515위  12999807     12999807         9398       0.07%
# ..            ...        ...       ...          ...          ...         ...
# 92        772  억원  코스닥 1081위  14182641     14182641       145864       1.03%
# 93      1,495  억원   코스닥 626위  15050580     15050580        95268       0.63%
# 94      1,978  억원   코스닥 467위  39396554     39396554        91630       0.23%
# 95      1,661  억원   코스닥 568위  14200000     14200000       111174       0.78%
# 96  1조  2,569  억원   코스피 189위  29366322     29366322      3788688      12.90%
#
#     동일업종 PER 동일업종 등락률 코스피/코스닥  시가총액(억원)  시가총액순위(전처리)   52주최고   52주최저   52주차액  \
# 0     1020.0   -1.79%     코스피      3108          458   45600    9150   36450
# 1     2422.0   -3.12%     코스닥      2699          322   54400   27050   27350
# 2     1020.0   -1.79%     코스피      3565          416    6200    3000    3200
# 3     5411.0   -4.45%     코스닥     93030            2  575100  145200  429900
# 4     3469.0   -3.76%     코스닥      1794          515   36550   13050   23500
# ..       ...      ...     ...       ...          ...     ...     ...     ...
# 92    3883.0   -3.83%     코스닥       772         1081   11900    2850    9050
# 93    2422.0   -2.94%     코스닥      1495          626   14000    7450    6550
# 94    1286.0   -2.16%     코스닥      1978          467    6530    2580    3950
# 95    3469.0   -3.76%     코스닥      1661          568   16400    8390    8010
# 96    1040.0   -4.29%     코스피     12569          189   67800   38350   29450
#
#      52주차액비율    현재-최고가  현재/최고가비율  투자의견      목표주가 매수매도 PER(배)_y  EPS(원)_y  \
# 0   4.983607  -17550.0  0.615132   NaN       NaN  NaN   30.51배     926.0
# 1   2.011091  -16350.0  0.699449   NaN       NaN  NaN      NaN   -1064.0
# 2   2.066667   -2230.0  0.640323   NaN       NaN  NaN      NaN    -184.0
# 3   3.960744 -169700.0  0.704921   4.0  628488.0   매수  109.17배    3718.0
# 4   2.800766  -22750.0  0.377565   NaN       NaN  NaN   39.09배     353.0
# ..       ...       ...       ...   ...       ...  ...      ...       ...
# 92  4.175439   -6500.0  0.453782   NaN       NaN  NaN      NaN    -366.0
# 93  1.879195   -4180.0  0.701429   NaN       NaN  NaN   20.60배     482.0
# 94  2.531008   -1595.0  0.755743   NaN       NaN  NaN      NaN    -128.0
# 95  1.954708   -4900.0  0.701220   NaN       NaN  NaN   49.58배     236.0
# 96  1.767927  -25100.0  0.629794   4.0   65375.0   매수   21.49배    1992.0
#
#     PBR(배)_y  BPS(원)_y        배당수익률기간  배당수익률%
# 0       2.61   10809.0            NaN     NaN
# 1       4.93    7752.0            NaN     NaN
# 2       1.51    2637.0            NaN     NaN
# 3      17.28   23486.0  배당수익률l2021.12    0.23
# 4       1.28   10772.0            NaN     NaN
# ..       ...       ...            ...     ...
# 92      3.39    1607.0            NaN     NaN
# 93      1.53    6505.0  배당수익률l2021.12    1.01
# 94      8.14     617.0            NaN     NaN
# 95      1.90    6165.0            NaN     NaN
# 96      4.06   10552.0            NaN     NaN
#
# [97 rows x 48 columns]

# %%
# 결측치수가 많거나 중복된 컬럼이 있는지 확인합니다.
df_final.shape
# Out:
# (97, 48)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 0 to 96
# Data columns (total 48 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   종목명          97 non-null     object
#  1   종목명.1        97 non-null     object
#  2   현재가          97 non-null     float64
#  3   전일비          97 non-null     float64
#  4   등락률          97 non-null     object
#  5   매수호가         97 non-null     float64
#  6   매도호가         97 non-null     float64
#  7   거래량          97 non-null     float64
#  8   거래대금         97 non-null     float64
#  9   전일거래량        97 non-null     float64
#  10  조회일자         97 non-null     object
#  11  종목명_전처리      97 non-null     object
#  12  종목코드         97 non-null     object
#  13  매출액          34 non-null     float64
#  14  영업이익         34 non-null     float64
#  15  당기순이익        23 non-null     float64
#  16  영업이익률        34 non-null     float64
#  17  순이익률         23 non-null     float64
#  18  EPS(원)_x     27 non-null     float64
#  19  PER(배)_x     27 non-null     float64
#  20  BPS(원)_x     35 non-null     float64
#  21  PBR(배)_x     35 non-null     float64
#  22  시가총액         97 non-null     object
#  23  시가총액순위       97 non-null     object
#  24  상장주식수        97 non-null     int64
#  25  외국인한도주식수(A)  97 non-null     int64
#  26  외국인보유주식수(B)  97 non-null     int64
#  27  외국인소진율(B/A)  97 non-null     object
#  28  동일업종 PER     97 non-null     float64
#  29  동일업종 등락률     97 non-null     object
#  30  코스피/코스닥      97 non-null     object
#  31  시가총액(억원)     97 non-null     int32
#  32  시가총액순위(전처리)  97 non-null     int32
#  33  52주최고        97 non-null     int32
#  34  52주최저        97 non-null     int32
#  35  52주차액        97 non-null     int32
#  36  52주차액비율      96 non-null     float64
#  37  현재-최고가       97 non-null     float64
#  38  현재/최고가비율     97 non-null     float64
#  39  투자의견         31 non-null     float64
#  40  목표주가         31 non-null     float64
#  41  매수매도         31 non-null     object
#  42  PER(배)_y     66 non-null     object
#  43  EPS(원)_y     95 non-null     float64
#  44  PBR(배)_y     95 non-null     float64
#  45  BPS(원)_y     95 non-null     float64
#  46  배당수익률기간      7 non-null      object
#  47  배당수익률%       7 non-null      float64
# dtypes: float64(26), int32(5), int64(3), object(14)
# memory usage: 35.2+ KB

# %%
# 전처리한 컬럼은 원본 컬럼을 제거합니다.
del_cols2 = ['종목명_전처리', '시가총액', '시가총액순위', '배당수익률기간']

# %%
# del_cols2 를 제거합니다.
df_final = df_final.drop(del_cols2, axis=1)
df_final
# Out:
#          종목명     종목명.1       현재가     전일비      등락률      매수호가      매도호가  \
# 0      삼아알미늄  테마 편입 사유   28050.0  1100.0   +4.08%   28150.0   28200.0
# 1     에이프로 *  테마 편입 사유   38050.0   800.0   +2.15%   38150.0   38200.0
# 2        알루코  테마 편입 사유    3970.0    60.0   +1.53%    4005.0    4010.0
# 3   에코프로비엠 *  테마 편입 사유  405400.0  5000.0   +1.25%  405000.0  405100.0
# 4     원방테크 *  테마 편입 사유   13800.0   150.0   +1.10%   13850.0   13900.0
# ..       ...       ...       ...     ...      ...       ...       ...
# 92    디이엔티 *  테마 편입 사유    5400.0   570.0   -9.55%    5380.0    5390.0
# 93    브이원텍 *  테마 편입 사유    9820.0  1230.0  -11.13%    9920.0    9940.0
# 94    나인테크 *  테마 편입 사유    4935.0   645.0  -11.56%    5030.0    5040.0
# 95   나라엠앤디 *  테마 편입 사유   11500.0  1550.0  -11.88%   11750.0   11800.0
# 96    PI첨단소재  테마 편입 사유   42700.0  6950.0  -14.00%   42750.0   42800.0
#
#            거래량      거래대금       전일거래량        조회일자    종목코드     매출액   영업이익  \
# 0     470144.0   13046.0    133848.0  2022-01-25  006110     NaN    NaN
# 1     217060.0    8314.0   1656641.0  2022-01-25  262260     NaN    NaN
# 2   23287831.0   97848.0   4906626.0  2022-01-25  001780     NaN    NaN
# 3     316436.0  129130.0    730341.0  2022-01-25  247540  4443.0  403.0
# 4     317443.0    4527.0    133205.0  2022-01-25  053080     NaN    NaN
# ..         ...       ...         ...         ...     ...     ...    ...
# 92    283199.0    1566.0    410992.0  2022-01-25  079810     NaN    NaN
# 93    633024.0    6493.0    508320.0  2022-01-25  251630     NaN    NaN
# 94   3407339.0   17772.0  12491739.0  2022-01-25  267320     NaN    NaN
# 95   1410582.0   17167.0   1864384.0  2022-01-25  051490     NaN    NaN
# 96    814638.0   35939.0    212149.0  2022-01-25  178920   718.0  152.0
#
#     당기순이익  영업이익률   순이익률  EPS(원)_x  PER(배)_x  BPS(원)_x  PBR(배)_x     상장주식수  \
# 0     NaN    NaN    NaN       NaN       NaN       NaN       NaN  11000000
# 1     NaN    NaN    NaN       NaN       NaN    8236.0      4.52   7065942
# 2     NaN    NaN    NaN       NaN       NaN       NaN       NaN  89791232
# 3   332.0   9.08   7.46    1423.0    281.34   31929.0     12.54  22919466
# 4     NaN    NaN    NaN       NaN       NaN       NaN       NaN  12999807
# ..    ...    ...    ...       ...       ...       ...       ...       ...
# 92    NaN    NaN    NaN       NaN       NaN       NaN       NaN  14182641
# 93    NaN    NaN    NaN       NaN       NaN    6221.0      1.78  15050580
# 94    NaN    NaN    NaN       NaN       NaN       NaN       NaN  39396554
# 95    NaN    NaN    NaN       NaN       NaN       NaN       NaN  14200000
# 96  106.0  21.16  14.81     362.0    141.72   10882.0      4.71  29366322
#
#     외국인한도주식수(A)  외국인보유주식수(B) 외국인소진율(B/A)  동일업종 PER 동일업종 등락률 코스피/코스닥  시가총액(억원)  \
# 0      11000000      3653946      33.22%    1020.0   -1.79%     코스피      3108
# 1       7065942        53295       0.75%    2422.0   -3.12%     코스닥      2699
# 2      89791232      1612229       1.80%    1020.0   -1.79%     코스피      3565
# 3      22919466      3613998      15.77%    5411.0   -4.45%     코스닥     93030
# 4      12999807         9398       0.07%    3469.0   -3.76%     코스닥      1794
# ..          ...          ...         ...       ...      ...     ...       ...
# 92     14182641       145864       1.03%    3883.0   -3.83%     코스닥       772
# 93     15050580        95268       0.63%    2422.0   -2.94%     코스닥      1495
# 94     39396554        91630       0.23%    1286.0   -2.16%     코스닥      1978
# 95     14200000       111174       0.78%    3469.0   -3.76%     코스닥      1661
# 96     29366322      3788688      12.90%    1040.0   -4.29%     코스피     12569
#
#     시가총액순위(전처리)   52주최고   52주최저   52주차액   52주차액비율    현재-최고가  현재/최고가비율  투자의견  \
# 0           458   45600    9150   36450  4.983607  -17550.0  0.615132   NaN
# 1           322   54400   27050   27350  2.011091  -16350.0  0.699449   NaN
# 2           416    6200    3000    3200  2.066667   -2230.0  0.640323   NaN
# 3             2  575100  145200  429900  3.960744 -169700.0  0.704921   4.0
# 4           515   36550   13050   23500  2.800766  -22750.0  0.377565   NaN
# ..          ...     ...     ...     ...       ...       ...       ...   ...
# 92         1081   11900    2850    9050  4.175439   -6500.0  0.453782   NaN
# 93          626   14000    7450    6550  1.879195   -4180.0  0.701429   NaN
# 94          467    6530    2580    3950  2.531008   -1595.0  0.755743   NaN
# 95          568   16400    8390    8010  1.954708   -4900.0  0.701220   NaN
# 96          189   67800   38350   29450  1.767927  -25100.0  0.629794   4.0
#
#         목표주가 매수매도 PER(배)_y  EPS(원)_y  PBR(배)_y  BPS(원)_y  배당수익률%
# 0        NaN  NaN   30.51배     926.0      2.61   10809.0     NaN
# 1        NaN  NaN      NaN   -1064.0      4.93    7752.0     NaN
# 2        NaN  NaN      NaN    -184.0      1.51    2637.0     NaN
# 3   628488.0   매수  109.17배    3718.0     17.28   23486.0    0.23
# 4        NaN  NaN   39.09배     353.0      1.28   10772.0     NaN
# ..       ...  ...      ...       ...       ...       ...     ...
# 92       NaN  NaN      NaN    -366.0      3.39    1607.0     NaN
# 93       NaN  NaN   20.60배     482.0      1.53    6505.0    1.01
# 94       NaN  NaN      NaN    -128.0      8.14     617.0     NaN
# 95       NaN  NaN   49.58배     236.0      1.90    6165.0     NaN
# 96   65375.0   매수   21.49배    1992.0      4.06   10552.0     NaN
#
# [97 rows x 44 columns]

# %%
# 컬럼명 중 필요없는 컬럼이 없는지 확인합니다.
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 0 to 96
# Data columns (total 44 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   종목명          97 non-null     object
#  1   종목명.1        97 non-null     object
#  2   현재가          97 non-null     float64
#  3   전일비          97 non-null     float64
#  4   등락률          97 non-null     object
#  5   매수호가         97 non-null     float64
#  6   매도호가         97 non-null     float64
#  7   거래량          97 non-null     float64
#  8   거래대금         97 non-null     float64
#  9   전일거래량        97 non-null     float64
#  10  조회일자         97 non-null     object
#  11  종목코드         97 non-null     object
#  12  매출액          34 non-null     float64
#  13  영업이익         34 non-null     float64
#  14  당기순이익        23 non-null     float64
#  15  영업이익률        34 non-null     float64
#  16  순이익률         23 non-null     float64
#  17  EPS(원)_x     27 non-null     float64
#  18  PER(배)_x     27 non-null     float64
#  19  BPS(원)_x     35 non-null     float64
#  20  PBR(배)_x     35 non-null     float64
#  21  상장주식수        97 non-null     int64
#  22  외국인한도주식수(A)  97 non-null     int64
#  23  외국인보유주식수(B)  97 non-null     int64
#  24  외국인소진율(B/A)  97 non-null     object
#  25  동일업종 PER     97 non-null     float64
#  26  동일업종 등락률     97 non-null     object
#  27  코스피/코스닥      97 non-null     object
#  28  시가총액(억원)     97 non-null     int32
#  29  시가총액순위(전처리)  97 non-null     int32
#  30  52주최고        97 non-null     int32
#  31  52주최저        97 non-null     int32
#  32  52주차액        97 non-null     int32
#  33  52주차액비율      96 non-null     float64
#  34  현재-최고가       97 non-null     float64
#  35  현재/최고가비율     97 non-null     float64
#  36  투자의견         31 non-null     float64
#  37  목표주가         31 non-null     float64
#  38  매수매도         31 non-null     object
#  39  PER(배)_y     66 non-null     object
#  40  EPS(원)_y     95 non-null     float64
#  41  PBR(배)_y     95 non-null     float64
#  42  BPS(원)_y     95 non-null     float64
#  43  배당수익률%       7 non-null      float64
# dtypes: float64(26), int32(5), int64(3), object(10)
# memory usage: 32.2+ KB

# %%
df_final.shape
# Out:
# (97, 44)

# %% [markdown]
# ## CSV 파일로 저장하기

# %%
# 기존 파일명을 변경해서 새로 저장할 파일명을 만듭니다.
file_name
# Out:
# 'theme_no_64_2022-01-25.csv'

# %%
# 저장할 파일명을 만들어 줍니다.
# 기존 파일명에 _ver2 를 붙여줍니다.
final_file_name = file_name.replace(".csv","_ver2.csv")
final_file_name
# Out:
# 'theme_no_64_2022-01-25_ver2.csv'

# %%
# final_file_name 변수에 있는 파일명으로 저장합니다.
df_final.to_csv(final_file_name, index=False)

# %%
# final_file_name 변수에 있는 값을 읽어옵니다.
# 이 때, 종목코드는 dtype={"종목코드":np.object} 로 불러옵니다.
pd.read_csv(final_file_name, dtype={"종목코드":np.object})
# Out:
# C:\Users\wkdwoo\AppData\Local\Temp/ipykernel_21516/3949739495.py:3: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pd.read_csv(final_file_name, dtype={"종목코드":np.object})
#          종목명     종목명.1       현재가     전일비      등락률      매수호가      매도호가  \
# 0      삼아알미늄  테마 편입 사유   28050.0  1100.0   +4.08%   28150.0   28200.0
# 1     에이프로 *  테마 편입 사유   38050.0   800.0   +2.15%   38150.0   38200.0
# 2        알루코  테마 편입 사유    3970.0    60.0   +1.53%    4005.0    4010.0
# 3   에코프로비엠 *  테마 편입 사유  405400.0  5000.0   +1.25%  405000.0  405100.0
# 4     원방테크 *  테마 편입 사유   13800.0   150.0   +1.10%   13850.0   13900.0
# ..       ...       ...       ...     ...      ...       ...       ...
# 92    디이엔티 *  테마 편입 사유    5400.0   570.0   -9.55%    5380.0    5390.0
# 93    브이원텍 *  테마 편입 사유    9820.0  1230.0  -11.13%    9920.0    9940.0
# 94    나인테크 *  테마 편입 사유    4935.0   645.0  -11.56%    5030.0    5040.0
# 95   나라엠앤디 *  테마 편입 사유   11500.0  1550.0  -11.88%   11750.0   11800.0
# 96    PI첨단소재  테마 편입 사유   42700.0  6950.0  -14.00%   42750.0   42800.0
#
#            거래량      거래대금       전일거래량        조회일자    종목코드     매출액   영업이익  \
# 0     470144.0   13046.0    133848.0  2022-01-25  006110     NaN    NaN
# 1     217060.0    8314.0   1656641.0  2022-01-25  262260     NaN    NaN
# 2   23287831.0   97848.0   4906626.0  2022-01-25  001780     NaN    NaN
# 3     316436.0  129130.0    730341.0  2022-01-25  247540  4443.0  403.0
# 4     317443.0    4527.0    133205.0  2022-01-25  053080     NaN    NaN
# ..         ...       ...         ...         ...     ...     ...    ...
# 92    283199.0    1566.0    410992.0  2022-01-25  079810     NaN    NaN
# 93    633024.0    6493.0    508320.0  2022-01-25  251630     NaN    NaN
# 94   3407339.0   17772.0  12491739.0  2022-01-25  267320     NaN    NaN
# 95   1410582.0   17167.0   1864384.0  2022-01-25  051490     NaN    NaN
# 96    814638.0   35939.0    212149.0  2022-01-25  178920   718.0  152.0
#
#     당기순이익  영업이익률   순이익률  EPS(원)_x  PER(배)_x  BPS(원)_x  PBR(배)_x     상장주식수  \
# 0     NaN    NaN    NaN       NaN       NaN       NaN       NaN  11000000
# 1     NaN    NaN    NaN       NaN       NaN    8236.0      4.52   7065942
# 2     NaN    NaN    NaN       NaN       NaN       NaN       NaN  89791232
# 3   332.0   9.08   7.46    1423.0    281.34   31929.0     12.54  22919466
# 4     NaN    NaN    NaN       NaN       NaN       NaN       NaN  12999807
# ..    ...    ...    ...       ...       ...       ...       ...       ...
# 92    NaN    NaN    NaN       NaN       NaN       NaN       NaN  14182641
# 93    NaN    NaN    NaN       NaN       NaN    6221.0      1.78  15050580
# 94    NaN    NaN    NaN       NaN       NaN       NaN       NaN  39396554
# 95    NaN    NaN    NaN       NaN       NaN       NaN       NaN  14200000
# 96  106.0  21.16  14.81     362.0    141.72   10882.0      4.71  29366322
#
#     외국인한도주식수(A)  외국인보유주식수(B) 외국인소진율(B/A)  동일업종 PER 동일업종 등락률 코스피/코스닥  시가총액(억원)  \
# 0      11000000      3653946      33.22%    1020.0   -1.79%     코스피      3108
# 1       7065942        53295       0.75%    2422.0   -3.12%     코스닥      2699
# 2      89791232      1612229       1.80%    1020.0   -1.79%     코스피      3565
# 3      22919466      3613998      15.77%    5411.0   -4.45%     코스닥     93030
# 4      12999807         9398       0.07%    3469.0   -3.76%     코스닥      1794
# ..          ...          ...         ...       ...      ...     ...       ...
# 92     14182641       145864       1.03%    3883.0   -3.83%     코스닥       772
# 93     15050580        95268       0.63%    2422.0   -2.94%     코스닥      1495
# 94     39396554        91630       0.23%    1286.0   -2.16%     코스닥      1978
# 95     14200000       111174       0.78%    3469.0   -3.76%     코스닥      1661
# 96     29366322      3788688      12.90%    1040.0   -4.29%     코스피     12569
#
#     시가총액순위(전처리)   52주최고   52주최저   52주차액   52주차액비율    현재-최고가  현재/최고가비율  투자의견  \
# 0           458   45600    9150   36450  4.983607  -17550.0  0.615132   NaN
# 1           322   54400   27050   27350  2.011091  -16350.0  0.699449   NaN
# 2           416    6200    3000    3200  2.066667   -2230.0  0.640323   NaN
# 3             2  575100  145200  429900  3.960744 -169700.0  0.704921   4.0
# 4           515   36550   13050   23500  2.800766  -22750.0  0.377565   NaN
# ..          ...     ...     ...     ...       ...       ...       ...   ...
# 92         1081   11900    2850    9050  4.175439   -6500.0  0.453782   NaN
# 93          626   14000    7450    6550  1.879195   -4180.0  0.701429   NaN
# 94          467    6530    2580    3950  2.531008   -1595.0  0.755743   NaN
# 95          568   16400    8390    8010  1.954708   -4900.0  0.701220   NaN
# 96          189   67800   38350   29450  1.767927  -25100.0  0.629794   4.0
#
#         목표주가 매수매도 PER(배)_y  EPS(원)_y  PBR(배)_y  BPS(원)_y  배당수익률%
# 0        NaN  NaN   30.51배     926.0      2.61   10809.0     NaN
# 1        NaN  NaN      NaN   -1064.0      4.93    7752.0     NaN
# 2        NaN  NaN      NaN    -184.0      1.51    2637.0     NaN
# 3   628488.0   매수  109.17배    3718.0     17.28   23486.0    0.23
# 4        NaN  NaN   39.09배     353.0      1.28   10772.0     NaN
# ..       ...  ...      ...       ...       ...       ...     ...
# 92       NaN  NaN      NaN    -366.0      3.39    1607.0     NaN
# 93       NaN  NaN   20.60배     482.0      1.53    6505.0    1.01
# 94       NaN  NaN      NaN    -128.0      8.14     617.0     NaN
# 95       NaN  NaN   49.58배     236.0      1.90    6165.0     NaN
# 96   65375.0   매수   21.49배    1992.0      4.06   10552.0     NaN
#
# [97 rows x 44 columns]
